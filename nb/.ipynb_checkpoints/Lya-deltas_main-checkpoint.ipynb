# %%
import numpy as np
import scipy as sp
from astropy.io import fits as pyfits
from astropy.table import Table
import desispec.io
from desispec.interpolation import resample_flux
#from desitarget.targetmask import desi_mask
#import sys
import os

import scipy.optimize as scpo
import matplotlib.pyplot as plt

import fitsio

# Desi catalog test
import glob
from itertools import compress
import healpy

import empca

# %%
####  Catalog cutter eBoss
def cat_cutter_eBoss( Nnew ):
   file = '/work3/desi_lya/data/eBOSS/dr15_all/DR14Q_v4_4.fits' # Add here the filename, include the full path if necesary
   output = '/home/sfbeltranv/respaldo/DR14_mini/DR14Q_v4_4m.fits'
   output = '/home/sfbeltranv/respaldo/DR14_mini/picca150000.fits'
   #file = '/work3/desi_lya/mocks_quick/london/v9.0.0_small/zcat_drq.fits'
   #output = '/home/sfbeltranv/respaldo/DR14_mini/zcatdrq_m.fits'

   hdul = pyfits.open(file)
   data = hdul[1].data
   hdul.info()

   # Nor: Origina size, Nnew: new size for the catalog (in overall items)
   Nor = len(data)
   print(Nor)
   #Nnew = 10000

   # Random Mask of Nnew items from the Nor items of the orignal catalog
   w = np.random.choice(Nor,Nnew,replace=False)

   if os.path.exists(output):
     os.remove(output)

   # Mask set in the catalog
   hdul[1].data = data[w]
   hdul.writeto(output)   # change name to the desired one.
   hdul.close()
   print('\n\nDone writing.\n')


   hdul = pyfits.open( output )
   data = hdul[1].data
   hdul.info()
   hdul.close() 
   print('\nDone with final size= ', len(data) )

#cat_cutter_eBoss(10000)

# %%
####  Catalog cutter Desi
def cat_cutter_Desi( Nnew ):
   

   file = '/work3/desi_lya/mocks_quick/london/v9.0.0_small/zcat.fits' # Add here the filename, include the full path if necesary
   output = '/home/sfbeltranv/respaldo/DR14_mini/zcat_m.fits'
   output = '/work/sfbeltranv/lya-blinding/oneCat.fits'

   hdul = pyfits.open(file)
   data = hdul[1].data
   hdul.info()

   # Nor: Origina size, Nnew: new size for the catalog (in overall items)
   Nor = len(data)
   #Nnew = 10000

   # Random Mask of Nnew items from the Nor items of the orignal catalog
   w = np.random.choice(Nor,Nnew,replace=False)

   if os.path.exists(output):
     os.remove(output)

   # Mask set in the catalog
   hdul[1].data = data[w]
   hdul.writeto(output)   # change name to the desired one.
   hdul.close()
   print('\n\nDone writing.\n')


   hdul = pyfits.open( output )
   data = hdul[1].data
   hdul.info()
   hdul.close() 
   print('\nDone with final size= ', len(data) )
      
#cat_cutter_Desi( 4 )

# %%
def normalizeSpec( x, y, xmin, xmax, normfactor = 6):
   
   xrange =  (x > xmin ) & (x < xmax ) 
   
   return y / ( np.sum(y[xrange]) * (x[1]-x[0]) ) * normfactor

def load_eBoss(path_drq, path_spec, zmin, zmax, lmin, lmax):
   # eBoss Catalog load
   catalog = Table.read(path_drq)
   
   w = (catalog['THING_ID']>0) & (catalog['Z'] > zmin ) & (catalog['Z']< zmax ) & (catalog['RA']!=catalog['DEC'])& (catalog['RA']>0) & (catalog['DEC']>0)
   reduced_cat = catalog[w]
   reduced_cat = reduced_cat.group_by('PLATE')

   nest = True
   in_nside = 16
   
   thing_id = reduced_cat['THING_ID']
   fiberid = reduced_cat['FIBERID']
   plate = reduced_cat['PLATE']
   zqso = reduced_cat['Z']
   DEC = reduced_cat['DEC']* np.pi/180
   RA = reduced_cat['RA']* np.pi/180

   plate_list=[]
   for p,m in zip(reduced_cat['PLATE'],reduced_cat['MJD']):
        plate_list.append(str(p)+'/spPlate-'+str(p)+'-'+str(m)+'.fits')
   plate_list=np.unique(plate_list)

    #thisplate=plate_list[0].split("/")[1]  # Location
    #thisplate=plate_list[0].split("/")[0]  # Plate Number
   print('Found '+ str(  np.sum(w) ) + ' QSO spec. in ' +str(len(plate_list))+ ' files of catalog: '+ path_drq )
    
   spectra = []
   QSOloc = []
   ## begin for test
   for nplate in range ( 0, len(plate_list) ):      # len(plate_list)
      plate1=pyfits.open( path_spec+'/'+plate_list[nplate].split("/")[1] )
      thisplate=plate_list[nplate].split("/")[0]  # Plate Number

      wp = plate == int( thisplate )
      ids_=fiberid[wp]
      tids_=thing_id[wp]
      zqso_=zqso[wp]
      DEC_ = DEC[wp]
      RA_ = RA[wp]
      
      nqsoPlate_= ids_.shape[0]
      print( str(nplate) + ': Loading '+ str(nqsoPlate_) +' QSO spec. from plate: '+ plate_list[nplate].split("/")[1] )
      # Reading data from plate
      plugmap = plate1['PLUGMAP'].data
      # Searching for fiber of qso in data
      wp = np.in1d(plugmap['FIBERID'],ids_)
      # Applying mask to select only QSO
      small_plugmap = plugmap[wp]

      #Get the spectra
      flux=plate1[0].data
      #Get the weight
      ivar=plate1[1].data

      #Get the wavelenght
      pltheader=plate1[0].header
      coeff0=pltheader['COEFF0']
      coeff1=pltheader['COEFF1']
      logwave=coeff0+coeff1*np.arange(flux.shape[1])
      for i in range(0,nqsoPlate_):
            w_ = (10**logwave)/(1+zqso_[i])
            w_crop = ( w_ >= lmin ) & ( w_ <= lmax )
            w_ = w_[w_crop]
            flx = flux[ids_[i]-1][w_crop]
            ivr = ivar[ids_[i]-1][w_crop]
            flx = normalizeSpec( w_, flx, 1300, 1500)
            
            heal_pix = healpy.ang2pix(in_nside, sp.pi/2.-DEC_[i], RA_[i], nest)
            
            QSOloc.append( np.hstack(( zqso_[i], DEC_[i], RA_[i], tids_[i]  )) )
            s=np.vstack( ( w_.conj().transpose(), flx.conj().transpose(), ivr.conj().transpose() ) )
            spectra.append( s )
   print('Reading done.')   
   return QSOloc, spectra


#####################################
# Load QSO from plates     eBoss
### Parameters
path_spec      = '/work3/desi_lya/data/eBOSS/dr15_all/spplates'
path_drq       = '/home/sfbeltranv/respaldo/DR14_mini/picca5000.fits'

# for line correction (later)
#path_lines     = '/work3/desi_lya/data/eBOSS/dr12_all/dr16-line-sky-mask.txt'

zmin = 2
zmax = 4

lmin = 1040
lmax = 1600

QSOloc_eBoss, spectra_eBoss = load_eBoss(path_drq, path_spec, zmin, zmax, lmin, lmax)
# Out:
# WARNING: UnitsWarning: 'erg/s/cm2' contains multiple slashes, which is discouraged by the FITS standard [astropy.units.format.generic]
# WARNING: UnitsWarning: 'W/m2/Hz' contains multiple slashes, which is discouraged by the FITS standard [astropy.units.format.generic]
# Found 1899 QSO spec. in 1313 files of catalog: /home/sfbeltranv/respaldo/DR14_mini/picca5000.fits
# 0: Loading 1 QSO spec. from plate: spPlate-3586-55181.fits
# 1: Loading 1 QSO spec. from plate: spPlate-3606-55182.fits
# 2: Loading 1 QSO spec. from plate: spPlate-3615-55179.fits
# 3: Loading 1 QSO spec. from plate: spPlate-3651-55247.fits
# 4: Loading 1 QSO spec. from plate: spPlate-3655-55240.fits
# 5: Loading 1 QSO spec. from plate: spPlate-3656-55241.fits
# 6: Loading 1 QSO spec. from plate: spPlate-3659-55181.fits
# 7: Loading 3 QSO spec. from plate: spPlate-3670-55480.fits
# 8: Loading 1 QSO spec. from plate: spPlate-3673-55178.fits
# 9: Loading 1 QSO spec. from plate: spPlate-3678-55208.fits
# 10: Loading 1 QSO spec. from plate: spPlate-3679-55209.fits
# 11: Loading 2 QSO spec. from plate: spPlate-3681-55243.fits
# 12: Loading 1 QSO spec. from plate: spPlate-3682-55244.fits
# 13: Loading 1 QSO spec. from plate: spPlate-3689-55180.fits
# 14: Loading 1 QSO spec. from plate: spPlate-3693-55208.fits
# 15: Loading 2 QSO spec. from plate: spPlate-3695-55212.fits
# 16: Loading 1 QSO spec. from plate: spPlate-3699-55517.fits
# 17: Loading 1 QSO spec. from plate: spPlate-3701-55540.fits
# 18: Loading 2 QSO spec. from plate: spPlate-3755-55504.fits
# 19: Loading 1 QSO spec. from plate: spPlate-3757-55508.fits
# 20: Loading 1 QSO spec. from plate: spPlate-3758-55506.fits
# 21: Loading 1 QSO spec. from plate: spPlate-3760-55268.fits
# 22: Loading 1 QSO spec. from plate: spPlate-3762-55507.fits
# 23: Loading 1 QSO spec. from plate: spPlate-3764-55514.fits
# 24: Loading 1 QSO spec. from plate: spPlate-3765-55508.fits
# 25: Loading 1 QSO spec. from plate: spPlate-3791-55501.fits
# 26: Loading 1 QSO spec. from plate: spPlate-3800-55486.fits
# 27: Loading 1 QSO spec. from plate: spPlate-3802-55528.fits
# 28: Loading 1 QSO spec. from plate: spPlate-3805-55269.fits
# 29: Loading 1 QSO spec. from plate: spPlate-3808-55513.fits
# 30: Loading 2 QSO spec. from plate: spPlate-3810-56015.fits
# 31: Loading 2 QSO spec. from plate: spPlate-3814-55535.fits
# 32: Loading 2 QSO spec. from plate: spPlate-3817-55277.fits
# 33: Loading 2 QSO spec. from plate: spPlate-3820-55542.fits
# 34: Loading 2 QSO spec. from plate: spPlate-3822-55544.fits
# 35: Loading 1 QSO spec. from plate: spPlate-3823-55534.fits
# 36: Loading 2 QSO spec. from plate: spPlate-3828-55539.fits
# 37: Loading 1 QSO spec. from plate: spPlate-3829-55300.fits
# 38: Loading 1 QSO spec. from plate: spPlate-3833-55290.fits
# 39: Loading 1 QSO spec. from plate: spPlate-3839-55575.fits
# 40: Loading 1 QSO spec. from plate: spPlate-3842-55565.fits
# 41: Loading 1 QSO spec. from plate: spPlate-3844-55321.fits
# 42: Loading 1 QSO spec. from plate: spPlate-3845-55323.fits
# 43: Loading 1 QSO spec. from plate: spPlate-3846-55327.fits
# 44: Loading 2 QSO spec. from plate: spPlate-3851-55302.fits
# 45: Loading 1 QSO spec. from plate: spPlate-3854-55247.fits
# 46: Loading 3 QSO spec. from plate: spPlate-3856-55269.fits
# 47: Loading 2 QSO spec. from plate: spPlate-3858-55273.fits
# 48: Loading 2 QSO spec. from plate: spPlate-3859-55246.fits
# 49: Loading 2 QSO spec. from plate: spPlate-3860-55269.fits
# 50: Loading 1 QSO spec. from plate: spPlate-3861-55274.fits
# 51: Loading 2 QSO spec. from plate: spPlate-3864-55649.fits
# 52: Loading 1 QSO spec. from plate: spPlate-3866-55623.fits
# 53: Loading 1 QSO spec. from plate: spPlate-3871-55307.fits
# 54: Loading 1 QSO spec. from plate: spPlate-3872-55382.fits
# 55: Loading 1 QSO spec. from plate: spPlate-3874-55280.fits
# 56: Loading 2 QSO spec. from plate: spPlate-3876-55245.fits
# 57: Loading 3 QSO spec. from plate: spPlate-3877-55365.fits
# 58: Loading 2 QSO spec. from plate: spPlate-3878-55361.fits
# 59: Loading 1 QSO spec. from plate: spPlate-3879-55244.fits
# 60: Loading 2 QSO spec. from plate: spPlate-3922-55333.fits
# 61: Loading 1 QSO spec. from plate: spPlate-3923-55325.fits
# 62: Loading 1 QSO spec. from plate: spPlate-3924-55332.fits
# 63: Loading 1 QSO spec. from plate: spPlate-3926-55327.fits
# 64: Loading 2 QSO spec. from plate: spPlate-3927-55333.fits
# 65: Loading 1 QSO spec. from plate: spPlate-3928-55331.fits
# 66: Loading 1 QSO spec. from plate: spPlate-3929-55335.fits
# 67: Loading 2 QSO spec. from plate: spPlate-3931-55350.fits
# 68: Loading 2 QSO spec. from plate: spPlate-3933-55335.fits
# 69: Loading 2 QSO spec. from plate: spPlate-3934-55336.fits
# 70: Loading 1 QSO spec. from plate: spPlate-3935-55326.fits
# 71: Loading 1 QSO spec. from plate: spPlate-3936-55302.fits
# 72: Loading 1 QSO spec. from plate: spPlate-3937-55352.fits
# 73: Loading 1 QSO spec. from plate: spPlate-3939-55633.fits
# 74: Loading 1 QSO spec. from plate: spPlate-3943-55336.fits
# 75: Loading 2 QSO spec. from plate: spPlate-3945-55648.fits
# 76: Loading 1 QSO spec. from plate: spPlate-3946-55659.fits
# 77: Loading 1 QSO spec. from plate: spPlate-3947-55332.fits
# 78: Loading 1 QSO spec. from plate: spPlate-3949-55650.fits
# 79: Loading 1 QSO spec. from plate: spPlate-3953-55322.fits
# 80: Loading 1 QSO spec. from plate: spPlate-3957-55664.fits
# 81: Loading 1 QSO spec. from plate: spPlate-3958-55329.fits
# 82: Loading 1 QSO spec. from plate: spPlate-3959-55679.fits
# 83: Loading 1 QSO spec. from plate: spPlate-3960-55663.fits
# 84: Loading 1 QSO spec. from plate: spPlate-3961-55654.fits
# 85: Loading 1 QSO spec. from plate: spPlate-3962-55660.fits
# 86: Loading 1 QSO spec. from plate: spPlate-3963-55659.fits
# 87: Loading 2 QSO spec. from plate: spPlate-3967-55704.fits
# 88: Loading 2 QSO spec. from plate: spPlate-3968-55590.fits
# 89: Loading 2 QSO spec. from plate: spPlate-3971-55322.fits
# 90: Loading 1 QSO spec. from plate: spPlate-3972-55589.fits
# 91: Loading 1 QSO spec. from plate: spPlate-3973-55323.fits
# 92: Loading 1 QSO spec. from plate: spPlate-3974-55320.fits
# 93: Loading 2 QSO spec. from plate: spPlate-3981-55603.fits
# 94: Loading 1 QSO spec. from plate: spPlate-3982-55332.fits
# 95: Loading 1 QSO spec. from plate: spPlate-3983-55603.fits
# 96: Loading 1 QSO spec. from plate: spPlate-3986-55329.fits
# 97: Loading 1 QSO spec. from plate: spPlate-4007-55327.fits
# 98: Loading 1 QSO spec. from plate: spPlate-4009-55648.fits
# 99: Loading 1 QSO spec. from plate: spPlate-4011-55635.fits
# 100: Loading 1 QSO spec. from plate: spPlate-4015-55624.fits
# 101: Loading 1 QSO spec. from plate: spPlate-4021-55620.fits
# 102: Loading 1 QSO spec. from plate: spPlate-4024-55646.fits
# 103: Loading 1 QSO spec. from plate: spPlate-4025-55350.fits
# 104: Loading 1 QSO spec. from plate: spPlate-4028-55621.fits
# 105: Loading 1 QSO spec. from plate: spPlate-4033-55332.fits
# 106: Loading 1 QSO spec. from plate: spPlate-4034-55635.fits
# 107: Loading 1 QSO spec. from plate: spPlate-4037-55631.fits
# 108: Loading 1 QSO spec. from plate: spPlate-4043-55630.fits
# 109: Loading 1 QSO spec. from plate: spPlate-4046-55605.fits
# 110: Loading 1 QSO spec. from plate: spPlate-4056-55357.fits
# 111: Loading 1 QSO spec. from plate: spPlate-4057-55357.fits
# 112: Loading 1 QSO spec. from plate: spPlate-4059-55360.fits
# 113: Loading 1 QSO spec. from plate: spPlate-4060-55359.fits
# 114: Loading 1 QSO spec. from plate: spPlate-4062-55383.fits
# 115: Loading 1 QSO spec. from plate: spPlate-4067-55361.fits
# 116: Loading 3 QSO spec. from plate: spPlate-4070-55681.fits
# 117: Loading 1 QSO spec. from plate: spPlate-4072-55362.fits
# 118: Loading 1 QSO spec. from plate: spPlate-4073-55663.fits
# 119: Loading 1 QSO spec. from plate: spPlate-4075-55352.fits
# 120: Loading 1 QSO spec. from plate: spPlate-4079-55363.fits
# 121: Loading 1 QSO spec. from plate: spPlate-4081-55365.fits
# 122: Loading 1 QSO spec. from plate: spPlate-4082-55367.fits
# 123: Loading 1 QSO spec. from plate: spPlate-4084-55447.fits
# 124: Loading 1 QSO spec. from plate: spPlate-4087-55449.fits
# 125: Loading 1 QSO spec. from plate: spPlate-4088-55451.fits
# 126: Loading 1 QSO spec. from plate: spPlate-4090-55500.fits
# 127: Loading 1 QSO spec. from plate: spPlate-4091-55498.fits
# 128: Loading 1 QSO spec. from plate: spPlate-4175-55680.fits
# 129: Loading 1 QSO spec. from plate: spPlate-4181-55685.fits
# 130: Loading 3 QSO spec. from plate: spPlate-4182-55446.fits
# 131: Loading 1 QSO spec. from plate: spPlate-4187-55693.fits
# 132: Loading 1 QSO spec. from plate: spPlate-4189-55679.fits
# 133: Loading 2 QSO spec. from plate: spPlate-4190-55686.fits
# 134: Loading 2 QSO spec. from plate: spPlate-4191-55444.fits
# 135: Loading 1 QSO spec. from plate: spPlate-4192-55469.fits
# 136: Loading 2 QSO spec. from plate: spPlate-4194-55450.fits
# 137: Loading 1 QSO spec. from plate: spPlate-4195-55452.fits
# 138: Loading 1 QSO spec. from plate: spPlate-4199-55481.fits
# 139: Loading 1 QSO spec. from plate: spPlate-4204-55470.fits
# 140: Loading 1 QSO spec. from plate: spPlate-4205-55454.fits
# 141: Loading 1 QSO spec. from plate: spPlate-4212-55447.fits
# 142: Loading 1 QSO spec. from plate: spPlate-4213-55449.fits
# 143: Loading 1 QSO spec. from plate: spPlate-4217-55478.fits
# 144: Loading 1 QSO spec. from plate: spPlate-4222-55444.fits
# 145: Loading 2 QSO spec. from plate: spPlate-4223-55451.fits
# 146: Loading 1 QSO spec. from plate: spPlate-4227-55481.fits
# 147: Loading 1 QSO spec. from plate: spPlate-4234-55478.fits
# 148: Loading 2 QSO spec. from plate: spPlate-4235-55451.fits
# 149: Loading 1 QSO spec. from plate: spPlate-4238-55455.fits
# 150: Loading 2 QSO spec. from plate: spPlate-4239-55458.fits
# 151: Loading 1 QSO spec. from plate: spPlate-4240-55455.fits
# 152: Loading 1 QSO spec. from plate: spPlate-4242-55476.fits
# 153: Loading 1 QSO spec. from plate: spPlate-4256-55477.fits
# 154: Loading 1 QSO spec. from plate: spPlate-4257-55480.fits
# 155: Loading 1 QSO spec. from plate: spPlate-4259-55501.fits
# 156: Loading 1 QSO spec. from plate: spPlate-4260-55478.fits
# 157: Loading 2 QSO spec. from plate: spPlate-4261-55503.fits
# 158: Loading 1 QSO spec. from plate: spPlate-4263-55484.fits
# 159: Loading 2 QSO spec. from plate: spPlate-4264-55506.fits
# 160: Loading 3 QSO spec. from plate: spPlate-4265-55505.fits
# 161: Loading 1 QSO spec. from plate: spPlate-4266-55486.fits
# 162: Loading 1 QSO spec. from plate: spPlate-4269-55502.fits
# 163: Loading 1 QSO spec. from plate: spPlate-4270-55511.fits
# 164: Loading 1 QSO spec. from plate: spPlate-4274-55508.fits
# 165: Loading 1 QSO spec. from plate: spPlate-4275-55501.fits
# 166: Loading 1 QSO spec. from plate: spPlate-4277-55506.fits
# 167: Loading 2 QSO spec. from plate: spPlate-4280-55503.fits
# 168: Loading 1 QSO spec. from plate: spPlate-4281-55836.fits
# 169: Loading 1 QSO spec. from plate: spPlate-4283-55864.fits
# 170: Loading 1 QSO spec. from plate: spPlate-4284-55863.fits
# 171: Loading 1 QSO spec. from plate: spPlate-4285-55881.fits
# 172: Loading 1 QSO spec. from plate: spPlate-4294-55500.fits
# 173: Loading 1 QSO spec. from plate: spPlate-4296-55499.fits
# 174: Loading 2 QSO spec. from plate: spPlate-4305-55509.fits
# 175: Loading 1 QSO spec. from plate: spPlate-4306-55584.fits
# 176: Loading 1 QSO spec. from plate: spPlate-4307-55531.fits
# 177: Loading 1 QSO spec. from plate: spPlate-4310-55508.fits
# 178: Loading 1 QSO spec. from plate: spPlate-4312-55511.fits
# 179: Loading 1 QSO spec. from plate: spPlate-4316-55505.fits
# 180: Loading 1 QSO spec. from plate: spPlate-4318-55508.fits
# 181: Loading 1 QSO spec. from plate: spPlate-4322-55503.fits
# 182: Loading 3 QSO spec. from plate: spPlate-4323-55884.fits
# 183: Loading 2 QSO spec. from plate: spPlate-4402-55514.fits
# 184: Loading 2 QSO spec. from plate: spPlate-4404-55513.fits
# 185: Loading 1 QSO spec. from plate: spPlate-4406-55858.fits
# 186: Loading 1 QSO spec. from plate: spPlate-4408-55888.fits
# 187: Loading 1 QSO spec. from plate: spPlate-4413-55894.fits
# 188: Loading 1 QSO spec. from plate: spPlate-4414-55882.fits
# 189: Loading 1 QSO spec. from plate: spPlate-4417-55829.fits
# 190: Loading 1 QSO spec. from plate: spPlate-4418-55862.fits
# 191: Loading 2 QSO spec. from plate: spPlate-4419-55867.fits
# 192: Loading 1 QSO spec. from plate: spPlate-4420-55883.fits
# 193: Loading 1 QSO spec. from plate: spPlate-4422-55533.fits
# 194: Loading 1 QSO spec. from plate: spPlate-4423-55889.fits
# 195: Loading 1 QSO spec. from plate: spPlate-4425-55864.fits
# 196: Loading 2 QSO spec. from plate: spPlate-4426-56105.fits
# 197: Loading 1 QSO spec. from plate: spPlate-4428-56189.fits
# 198: Loading 3 QSO spec. from plate: spPlate-4441-55532.fits
# 199: Loading 1 QSO spec. from plate: spPlate-4442-55532.fits
# 200: Loading 1 QSO spec. from plate: spPlate-4443-55539.fits
# 201: Loading 1 QSO spec. from plate: spPlate-4446-55589.fits
# 202: Loading 2 QSO spec. from plate: spPlate-4447-55542.fits
# 203: Loading 3 QSO spec. from plate: spPlate-4448-55538.fits
# 204: Loading 2 QSO spec. from plate: spPlate-4449-55544.fits
# 205: Loading 1 QSO spec. from plate: spPlate-4450-55540.fits
# 206: Loading 2 QSO spec. from plate: spPlate-4453-55535.fits
# 207: Loading 1 QSO spec. from plate: spPlate-4454-55536.fits
# 208: Loading 1 QSO spec. from plate: spPlate-4455-55539.fits
# 209: Loading 2 QSO spec. from plate: spPlate-4457-55858.fits
# 210: Loading 1 QSO spec. from plate: spPlate-4458-55536.fits
# 211: Loading 3 QSO spec. from plate: spPlate-4459-55533.fits
# 212: Loading 1 QSO spec. from plate: spPlate-4461-55888.fits
# 213: Loading 1 QSO spec. from plate: spPlate-4464-55866.fits
# 214: Loading 2 QSO spec. from plate: spPlate-4466-55857.fits
# 215: Loading 2 QSO spec. from plate: spPlate-4467-55894.fits
# 216: Loading 1 QSO spec. from plate: spPlate-4468-55894.fits
# 217: Loading 1 QSO spec. from plate: spPlate-4470-55587.fits
# 218: Loading 1 QSO spec. from plate: spPlate-4473-55589.fits
# 219: Loading 1 QSO spec. from plate: spPlate-4480-55591.fits
# 220: Loading 2 QSO spec. from plate: spPlate-4483-55587.fits
# 221: Loading 2 QSO spec. from plate: spPlate-4487-55866.fits
# 222: Loading 1 QSO spec. from plate: spPlate-4488-55571.fits
# 223: Loading 1 QSO spec. from plate: spPlate-4489-55545.fits
# 224: Loading 2 QSO spec. from plate: spPlate-4491-55570.fits
# 225: Loading 2 QSO spec. from plate: spPlate-4492-55565.fits
# 226: Loading 2 QSO spec. from plate: spPlate-4494-55569.fits
# 227: Loading 1 QSO spec. from plate: spPlate-4496-55544.fits
# 228: Loading 2 QSO spec. from plate: spPlate-4497-55564.fits
# 229: Loading 2 QSO spec. from plate: spPlate-4498-55615.fits
# 230: Loading 2 QSO spec. from plate: spPlate-4499-55572.fits
# 231: Loading 3 QSO spec. from plate: spPlate-4500-55543.fits
# 232: Loading 1 QSO spec. from plate: spPlate-4503-55563.fits
# 233: Loading 1 QSO spec. from plate: spPlate-4505-55603.fits
# 234: Loading 1 QSO spec. from plate: spPlate-4506-55568.fits
# 235: Loading 4 QSO spec. from plate: spPlate-4507-55564.fits
# 236: Loading 1 QSO spec. from plate: spPlate-4511-55602.fits
# 237: Loading 1 QSO spec. from plate: spPlate-4526-55559.fits
# 238: Loading 1 QSO spec. from plate: spPlate-4530-55564.fits
# 239: Loading 2 QSO spec. from plate: spPlate-4532-55559.fits
# 240: Loading 1 QSO spec. from plate: spPlate-4537-55806.fits
# 241: Loading 1 QSO spec. from plate: spPlate-4538-55860.fits
# 242: Loading 1 QSO spec. from plate: spPlate-4544-55855.fits
# 243: Loading 1 QSO spec. from plate: spPlate-4548-55565.fits
# 244: Loading 1 QSO spec. from plate: spPlate-4549-55556.fits
# 245: Loading 1 QSO spec. from plate: spPlate-4550-55894.fits
# 246: Loading 1 QSO spec. from plate: spPlate-4555-56189.fits
# 247: Loading 1 QSO spec. from plate: spPlate-4556-55912.fits
# 248: Loading 1 QSO spec. from plate: spPlate-4557-55588.fits
# 249: Loading 1 QSO spec. from plate: spPlate-4563-55617.fits
# 250: Loading 1 QSO spec. from plate: spPlate-4564-55570.fits
# 251: Loading 1 QSO spec. from plate: spPlate-4567-55589.fits
# 252: Loading 2 QSO spec. from plate: spPlate-4569-55631.fits
# 253: Loading 1 QSO spec. from plate: spPlate-4576-55592.fits
# 254: Loading 1 QSO spec. from plate: spPlate-4604-55983.fits
# 255: Loading 1 QSO spec. from plate: spPlate-4605-55971.fits
# 256: Loading 1 QSO spec. from plate: spPlate-4607-56248.fits
# 257: Loading 1 QSO spec. from plate: spPlate-4608-55973.fits
# 258: Loading 4 QSO spec. from plate: spPlate-4610-55621.fits
# 259: Loading 2 QSO spec. from plate: spPlate-4611-55603.fits
# 260: Loading 2 QSO spec. from plate: spPlate-4613-55591.fits
# 261: Loading 1 QSO spec. from plate: spPlate-4616-55617.fits
# 262: Loading 1 QSO spec. from plate: spPlate-4617-55617.fits
# 263: Loading 1 QSO spec. from plate: spPlate-4619-55599.fits
# 264: Loading 1 QSO spec. from plate: spPlate-4621-55649.fits
# 265: Loading 1 QSO spec. from plate: spPlate-4622-55629.fits
# 266: Loading 1 QSO spec. from plate: spPlate-4623-55621.fits
# 267: Loading 1 QSO spec. from plate: spPlate-4624-55654.fits
# 268: Loading 3 QSO spec. from plate: spPlate-4627-55626.fits
# 269: Loading 1 QSO spec. from plate: spPlate-4630-55623.fits
# 270: Loading 1 QSO spec. from plate: spPlate-4632-55644.fits
# 271: Loading 2 QSO spec. from plate: spPlate-4634-55626.fits
# 272: Loading 1 QSO spec. from plate: spPlate-4635-55615.fits
# 273: Loading 1 QSO spec. from plate: spPlate-4636-55945.fits
# 274: Loading 1 QSO spec. from plate: spPlate-4637-55616.fits
# 275: Loading 1 QSO spec. from plate: spPlate-4639-55944.fits
# 276: Loading 2 QSO spec. from plate: spPlate-4640-55927.fits
# 277: Loading 4 QSO spec. from plate: spPlate-4646-55622.fits
# 278: Loading 1 QSO spec. from plate: spPlate-4650-55648.fits
# 279: Loading 1 QSO spec. from plate: spPlate-4652-55672.fits
# 280: Loading 2 QSO spec. from plate: spPlate-4654-55659.fits
# 281: Loading 1 QSO spec. from plate: spPlate-4655-55620.fits
# 282: Loading 1 QSO spec. from plate: spPlate-4657-55591.fits
# 283: Loading 1 QSO spec. from plate: spPlate-4659-55587.fits
# 284: Loading 4 QSO spec. from plate: spPlate-4660-56191.fits
# 285: Loading 2 QSO spec. from plate: spPlate-4661-55614.fits
# 286: Loading 1 QSO spec. from plate: spPlate-4663-55893.fits
# 287: Loading 1 QSO spec. from plate: spPlate-4665-56209.fits
# 288: Loading 3 QSO spec. from plate: spPlate-4667-55868.fits
# 289: Loading 4 QSO spec. from plate: spPlate-4668-56211.fits
# 290: Loading 1 QSO spec. from plate: spPlate-4669-55831.fits
# 291: Loading 1 QSO spec. from plate: spPlate-4688-56008.fits
# 292: Loading 2 QSO spec. from plate: spPlate-4689-55656.fits
# 293: Loading 1 QSO spec. from plate: spPlate-4690-55653.fits
# 294: Loading 1 QSO spec. from plate: spPlate-4691-55651.fits
# 295: Loading 3 QSO spec. from plate: spPlate-4692-55644.fits
# 296: Loading 2 QSO spec. from plate: spPlate-4693-55632.fits
# 297: Loading 1 QSO spec. from plate: spPlate-4694-55649.fits
# 298: Loading 1 QSO spec. from plate: spPlate-4695-55957.fits
# 299: Loading 1 QSO spec. from plate: spPlate-4697-55660.fits
# 300: Loading 1 QSO spec. from plate: spPlate-4698-55623.fits
# 301: Loading 1 QSO spec. from plate: spPlate-4701-55709.fits
# 302: Loading 1 QSO spec. from plate: spPlate-4707-55653.fits
# 303: Loading 1 QSO spec. from plate: spPlate-4708-55704.fits
# 304: Loading 1 QSO spec. from plate: spPlate-4710-55707.fits
# 305: Loading 2 QSO spec. from plate: spPlate-4712-55738.fits
# 306: Loading 1 QSO spec. from plate: spPlate-4713-56044.fits
# 307: Loading 1 QSO spec. from plate: spPlate-4719-55736.fits
# 308: Loading 2 QSO spec. from plate: spPlate-4720-55691.fits
# 309: Loading 1 QSO spec. from plate: spPlate-4722-55735.fits
# 310: Loading 2 QSO spec. from plate: spPlate-4724-55742.fits
# 311: Loading 1 QSO spec. from plate: spPlate-4726-55712.fits
# 312: Loading 2 QSO spec. from plate: spPlate-4729-55626.fits
# 313: Loading 1 QSO spec. from plate: spPlate-4732-55648.fits
# 314: Loading 1 QSO spec. from plate: spPlate-4736-55631.fits
# 315: Loading 1 QSO spec. from plate: spPlate-4737-55630.fits
# 316: Loading 1 QSO spec. from plate: spPlate-4739-55644.fits
# 317: Loading 1 QSO spec. from plate: spPlate-4740-55651.fits
# 318: Loading 1 QSO spec. from plate: spPlate-4742-55660.fits
# 319: Loading 1 QSO spec. from plate: spPlate-4743-55645.fits
# 320: Loading 2 QSO spec. from plate: spPlate-4745-55892.fits
# 321: Loading 1 QSO spec. from plate: spPlate-4746-55632.fits
# 322: Loading 1 QSO spec. from plate: spPlate-4747-55652.fits
# 323: Loading 1 QSO spec. from plate: spPlate-4749-55633.fits
# 324: Loading 2 QSO spec. from plate: spPlate-4751-55646.fits
# 325: Loading 2 QSO spec. from plate: spPlate-4753-55674.fits
# 326: Loading 1 QSO spec. from plate: spPlate-4754-55649.fits
# 327: Loading 2 QSO spec. from plate: spPlate-4756-55631.fits
# 328: Loading 2 QSO spec. from plate: spPlate-4758-55682.fits
# 329: Loading 1 QSO spec. from plate: spPlate-4760-55656.fits
# 330: Loading 1 QSO spec. from plate: spPlate-4761-55633.fits
# 331: Loading 2 QSO spec. from plate: spPlate-4764-55646.fits
# 332: Loading 1 QSO spec. from plate: spPlate-4765-55674.fits
# 333: Loading 2 QSO spec. from plate: spPlate-4766-55677.fits
# 334: Loading 1 QSO spec. from plate: spPlate-4767-55946.fits
# 335: Loading 1 QSO spec. from plate: spPlate-4768-55944.fits
# 336: Loading 2 QSO spec. from plate: spPlate-4772-55654.fits
# 337: Loading 1 QSO spec. from plate: spPlate-4774-55659.fits
# 338: Loading 1 QSO spec. from plate: spPlate-4776-55652.fits
# 339: Loading 1 QSO spec. from plate: spPlate-4778-55706.fits
# 340: Loading 1 QSO spec. from plate: spPlate-4779-55656.fits
# 341: Loading 1 QSO spec. from plate: spPlate-4784-55677.fits
# 342: Loading 1 QSO spec. from plate: spPlate-4787-55863.fits
# 343: Loading 1 QSO spec. from plate: spPlate-4790-55888.fits
# 344: Loading 2 QSO spec. from plate: spPlate-4791-55889.fits
# 345: Loading 2 QSO spec. from plate: spPlate-4792-55925.fits
# 346: Loading 2 QSO spec. from plate: spPlate-4793-55648.fits
# 347: Loading 1 QSO spec. from plate: spPlate-4794-55647.fits
# 348: Loading 1 QSO spec. from plate: spPlate-4796-55924.fits
# 349: Loading 1 QSO spec. from plate: spPlate-4797-55662.fits
# 350: Loading 1 QSO spec. from plate: spPlate-4799-55656.fits
# 351: Loading 1 QSO spec. from plate: spPlate-4801-55653.fits
# 352: Loading 1 QSO spec. from plate: spPlate-4803-55734.fits
# 353: Loading 2 QSO spec. from plate: spPlate-4805-55715.fits
# 354: Loading 1 QSO spec. from plate: spPlate-4806-55688.fits
# 355: Loading 1 QSO spec. from plate: spPlate-4808-55705.fits
# 356: Loading 1 QSO spec. from plate: spPlate-4831-55679.fits
# 357: Loading 1 QSO spec. from plate: spPlate-4832-55680.fits
# 358: Loading 1 QSO spec. from plate: spPlate-4836-55689.fits
# 359: Loading 2 QSO spec. from plate: spPlate-4837-55707.fits
# 360: Loading 1 QSO spec. from plate: spPlate-4838-55686.fits
# 361: Loading 2 QSO spec. from plate: spPlate-4839-55703.fits
# 362: Loading 1 QSO spec. from plate: spPlate-4840-55690.fits
# 363: Loading 1 QSO spec. from plate: spPlate-4842-55867.fits
# 364: Loading 1 QSO spec. from plate: spPlate-4843-55860.fits
# 365: Loading 1 QSO spec. from plate: spPlate-4848-55955.fits
# 366: Loading 2 QSO spec. from plate: spPlate-4850-55929.fits
# 367: Loading 1 QSO spec. from plate: spPlate-4851-55680.fits
# 368: Loading 2 QSO spec. from plate: spPlate-4853-55928.fits
# 369: Loading 1 QSO spec. from plate: spPlate-4854-55685.fits
# 370: Loading 3 QSO spec. from plate: spPlate-4856-55712.fits
# 371: Loading 1 QSO spec. from plate: spPlate-4857-55711.fits
# 372: Loading 1 QSO spec. from plate: spPlate-4858-55686.fits
# 373: Loading 2 QSO spec. from plate: spPlate-4859-55684.fits
# 374: Loading 1 QSO spec. from plate: spPlate-4864-55680.fits
# 375: Loading 2 QSO spec. from plate: spPlate-4866-55895.fits
# 376: Loading 1 QSO spec. from plate: spPlate-4868-55895.fits
# 377: Loading 1 QSO spec. from plate: spPlate-4870-55923.fits
# 378: Loading 1 QSO spec. from plate: spPlate-4871-55928.fits
# 379: Loading 2 QSO spec. from plate: spPlate-4872-55944.fits
# 380: Loading 2 QSO spec. from plate: spPlate-4873-55926.fits
# 381: Loading 2 QSO spec. from plate: spPlate-4874-55673.fits
# 382: Loading 1 QSO spec. from plate: spPlate-4877-55707.fits
# 383: Loading 2 QSO spec. from plate: spPlate-4878-55710.fits
# 384: Loading 1 QSO spec. from plate: spPlate-4890-55741.fits
# 385: Loading 1 QSO spec. from plate: spPlate-4891-55736.fits
# 386: Loading 2 QSO spec. from plate: spPlate-4895-55708.fits
# 387: Loading 1 QSO spec. from plate: spPlate-4896-55712.fits
# 388: Loading 1 QSO spec. from plate: spPlate-4964-55749.fits
# 389: Loading 1 QSO spec. from plate: spPlate-4965-55721.fits
# 390: Loading 3 QSO spec. from plate: spPlate-4966-55712.fits
# 391: Loading 1 QSO spec. from plate: spPlate-4969-56041.fits
# 392: Loading 2 QSO spec. from plate: spPlate-4970-56039.fits
# 393: Loading 1 QSO spec. from plate: spPlate-4973-56042.fits
# 394: Loading 1 QSO spec. from plate: spPlate-4974-56038.fits
# 395: Loading 1 QSO spec. from plate: spPlate-4976-56046.fits
# 396: Loading 1 QSO spec. from plate: spPlate-4978-56036.fits
# 397: Loading 1 QSO spec. from plate: spPlate-4979-56045.fits
# 398: Loading 1 QSO spec. from plate: spPlate-4987-55746.fits
# 399: Loading 1 QSO spec. from plate: spPlate-4989-56069.fits
# 400: Loading 1 QSO spec. from plate: spPlate-4990-55743.fits
# 401: Loading 1 QSO spec. from plate: spPlate-4993-55738.fits
# 402: Loading 2 QSO spec. from plate: spPlate-4995-55739.fits
# 403: Loading 2 QSO spec. from plate: spPlate-4997-55738.fits
# 404: Loading 2 QSO spec. from plate: spPlate-5000-55715.fits
# 405: Loading 1 QSO spec. from plate: spPlate-5001-55719.fits
# 406: Loading 3 QSO spec. from plate: spPlate-5002-55710.fits
# 407: Loading 2 QSO spec. from plate: spPlate-5006-55706.fits
# 408: Loading 1 QSO spec. from plate: spPlate-5007-55710.fits
# 409: Loading 1 QSO spec. from plate: spPlate-5009-55707.fits
# 410: Loading 3 QSO spec. from plate: spPlate-5010-55748.fits
# 411: Loading 1 QSO spec. from plate: spPlate-5011-55739.fits
# 412: Loading 2 QSO spec. from plate: spPlate-5014-55717.fits
# 413: Loading 1 QSO spec. from plate: spPlate-5016-55709.fits
# 414: Loading 1 QSO spec. from plate: spPlate-5025-55836.fits
# 415: Loading 1 QSO spec. from plate: spPlate-5027-56218.fits
# 416: Loading 1 QSO spec. from plate: spPlate-5029-55750.fits
# 417: Loading 1 QSO spec. from plate: spPlate-5031-56209.fits
# 418: Loading 2 QSO spec. from plate: spPlate-5033-56244.fits
# 419: Loading 1 QSO spec. from plate: spPlate-5035-55829.fits
# 420: Loading 4 QSO spec. from plate: spPlate-5036-55751.fits
# 421: Loading 1 QSO spec. from plate: spPlate-5038-56235.fits
# 422: Loading 1 QSO spec. from plate: spPlate-5042-55856.fits
# 423: Loading 1 QSO spec. from plate: spPlate-5043-56187.fits
# 424: Loading 1 QSO spec. from plate: spPlate-5044-56186.fits
# 425: Loading 1 QSO spec. from plate: spPlate-5045-56181.fits
# 426: Loading 2 QSO spec. from plate: spPlate-5046-56243.fits
# 427: Loading 2 QSO spec. from plate: spPlate-5049-56103.fits
# 428: Loading 1 QSO spec. from plate: spPlate-5055-55889.fits
# 429: Loading 1 QSO spec. from plate: spPlate-5058-56208.fits
# 430: Loading 1 QSO spec. from plate: spPlate-5064-55864.fits
# 431: Loading 1 QSO spec. from plate: spPlate-5067-55751.fits
# 432: Loading 1 QSO spec. from plate: spPlate-5106-55833.fits
# 433: Loading 1 QSO spec. from plate: spPlate-5108-55888.fits
# 434: Loading 1 QSO spec. from plate: spPlate-5109-55892.fits
# 435: Loading 1 QSO spec. from plate: spPlate-5119-55836.fits
# 436: Loading 2 QSO spec. from plate: spPlate-5125-55863.fits
# 437: Loading 2 QSO spec. from plate: spPlate-5129-55864.fits
# 438: Loading 2 QSO spec. from plate: spPlate-5131-55835.fits
# 439: Loading 4 QSO spec. from plate: spPlate-5136-55836.fits
# 440: Loading 1 QSO spec. from plate: spPlate-5139-55866.fits
# 441: Loading 1 QSO spec. from plate: spPlate-5142-55825.fits
# 442: Loading 1 QSO spec. from plate: spPlate-5143-55828.fits
# 443: Loading 2 QSO spec. from plate: spPlate-5144-55829.fits
# 444: Loading 2 QSO spec. from plate: spPlate-5145-55835.fits
# 445: Loading 1 QSO spec. from plate: spPlate-5146-55831.fits
# 446: Loading 1 QSO spec. from plate: spPlate-5147-55854.fits
# 447: Loading 1 QSO spec. from plate: spPlate-5148-56220.fits
# 448: Loading 1 QSO spec. from plate: spPlate-5149-55944.fits
# 449: Loading 2 QSO spec. from plate: spPlate-5155-55946.fits
# 450: Loading 2 QSO spec. from plate: spPlate-5159-55856.fits
# 451: Loading 1 QSO spec. from plate: spPlate-5161-55968.fits
# 452: Loading 1 QSO spec. from plate: spPlate-5164-56067.fits
# 453: Loading 2 QSO spec. from plate: spPlate-5165-56063.fits
# 454: Loading 3 QSO spec. from plate: spPlate-5168-56035.fits
# 455: Loading 1 QSO spec. from plate: spPlate-5171-56038.fits
# 456: Loading 1 QSO spec. from plate: spPlate-5172-56071.fits
# 457: Loading 1 QSO spec. from plate: spPlate-5173-56046.fits
# 458: Loading 1 QSO spec. from plate: spPlate-5174-56047.fits
# 459: Loading 2 QSO spec. from plate: spPlate-5175-55955.fits
# 460: Loading 3 QSO spec. from plate: spPlate-5176-56221.fits
# 461: Loading 5 QSO spec. from plate: spPlate-5177-56245.fits
# 462: Loading 1 QSO spec. from plate: spPlate-5178-56246.fits
# 463: Loading 1 QSO spec. from plate: spPlate-5179-55957.fits
# 464: Loading 2 QSO spec. from plate: spPlate-5180-55947.fits
# 465: Loading 1 QSO spec. from plate: spPlate-5183-55976.fits
# 466: Loading 1 QSO spec. from plate: spPlate-5184-56352.fits
# 467: Loading 1 QSO spec. from plate: spPlate-5185-55978.fits
# 468: Loading 1 QSO spec. from plate: spPlate-5186-56337.fits
# 469: Loading 1 QSO spec. from plate: spPlate-5187-56074.fits
# 470: Loading 1 QSO spec. from plate: spPlate-5191-56065.fits
# 471: Loading 1 QSO spec. from plate: spPlate-5194-56062.fits
# 472: Loading 2 QSO spec. from plate: spPlate-5195-56048.fits
# 473: Loading 1 QSO spec. from plate: spPlate-5196-55831.fits
# 474: Loading 2 QSO spec. from plate: spPlate-5197-55828.fits
# 475: Loading 1 QSO spec. from plate: spPlate-5198-55823.fits
# 476: Loading 3 QSO spec. from plate: spPlate-5199-56067.fits
# 477: Loading 2 QSO spec. from plate: spPlate-5200-56091.fits
# 478: Loading 1 QSO spec. from plate: spPlate-5204-56036.fits
# 479: Loading 1 QSO spec. from plate: spPlate-5205-56040.fits
# 480: Loading 4 QSO spec. from plate: spPlate-5206-56033.fits
# 481: Loading 1 QSO spec. from plate: spPlate-5207-56018.fits
# 482: Loading 1 QSO spec. from plate: spPlate-5208-56008.fits
# 483: Loading 1 QSO spec. from plate: spPlate-5289-55893.fits
# 484: Loading 2 QSO spec. from plate: spPlate-5290-55862.fits
# 485: Loading 2 QSO spec. from plate: spPlate-5291-55947.fits
# 486: Loading 1 QSO spec. from plate: spPlate-5292-55926.fits
# 487: Loading 2 QSO spec. from plate: spPlate-5294-55922.fits
# 488: Loading 1 QSO spec. from plate: spPlate-5296-55922.fits
# 489: Loading 2 QSO spec. from plate: spPlate-5297-55913.fits
# 490: Loading 1 QSO spec. from plate: spPlate-5299-55927.fits
# 491: Loading 1 QSO spec. from plate: spPlate-5301-55987.fits
# 492: Loading 1 QSO spec. from plate: spPlate-5302-55896.fits
# 493: Loading 2 QSO spec. from plate: spPlate-5304-55925.fits
# 494: Loading 2 QSO spec. from plate: spPlate-5307-55998.fits
# 495: Loading 3 QSO spec. from plate: spPlate-5309-55929.fits
# 496: Loading 1 QSO spec. from plate: spPlate-5310-55983.fits
# 497: Loading 1 QSO spec. from plate: spPlate-5311-55956.fits
# 498: Loading 3 QSO spec. from plate: spPlate-5312-56001.fits
# 499: Loading 2 QSO spec. from plate: spPlate-5314-55952.fits
# 500: Loading 1 QSO spec. from plate: spPlate-5318-55983.fits
# 501: Loading 1 QSO spec. from plate: spPlate-5323-55957.fits
# 502: Loading 1 QSO spec. from plate: spPlate-5324-55947.fits
# 503: Loading 3 QSO spec. from plate: spPlate-5325-55980.fits
# 504: Loading 2 QSO spec. from plate: spPlate-5326-56002.fits
# 505: Loading 2 QSO spec. from plate: spPlate-5327-55979.fits
# 506: Loading 1 QSO spec. from plate: spPlate-5332-55981.fits
# 507: Loading 2 QSO spec. from plate: spPlate-5336-55957.fits
# 508: Loading 1 QSO spec. from plate: spPlate-5337-55987.fits
# 509: Loading 3 QSO spec. from plate: spPlate-5338-56002.fits
# 510: Loading 2 QSO spec. from plate: spPlate-5343-55999.fits
# 511: Loading 2 QSO spec. from plate: spPlate-5346-55955.fits
# 512: Loading 1 QSO spec. from plate: spPlate-5349-55929.fits
# 513: Loading 3 QSO spec. from plate: spPlate-5353-55980.fits
# 514: Loading 1 QSO spec. from plate: spPlate-5354-55927.fits
# 515: Loading 2 QSO spec. from plate: spPlate-5355-56009.fits
# 516: Loading 1 QSO spec. from plate: spPlate-5358-56016.fits
# 517: Loading 2 QSO spec. from plate: spPlate-5360-55983.fits
# 518: Loading 1 QSO spec. from plate: spPlate-5361-55973.fits
# 519: Loading 2 QSO spec. from plate: spPlate-5362-56017.fits
# 520: Loading 3 QSO spec. from plate: spPlate-5363-55956.fits
# 521: Loading 1 QSO spec. from plate: spPlate-5365-55945.fits
# 522: Loading 2 QSO spec. from plate: spPlate-5366-55958.fits
# 523: Loading 4 QSO spec. from plate: spPlate-5370-56003.fits
# 524: Loading 2 QSO spec. from plate: spPlate-5371-55976.fits
# 525: Loading 4 QSO spec. from plate: spPlate-5372-55978.fits
# 526: Loading 1 QSO spec. from plate: spPlate-5373-56010.fits
# 527: Loading 1 QSO spec. from plate: spPlate-5374-55947.fits
# 528: Loading 1 QSO spec. from plate: spPlate-5375-55973.fits
# 529: Loading 2 QSO spec. from plate: spPlate-5376-55987.fits
# 530: Loading 1 QSO spec. from plate: spPlate-5377-55957.fits
# 531: Loading 2 QSO spec. from plate: spPlate-5380-55980.fits
# 532: Loading 1 QSO spec. from plate: spPlate-5381-56009.fits
# 533: Loading 1 QSO spec. from plate: spPlate-5383-56013.fits
# 534: Loading 2 QSO spec. from plate: spPlate-5384-55984.fits
# 535: Loading 1 QSO spec. from plate: spPlate-5388-55983.fits
# 536: Loading 3 QSO spec. from plate: spPlate-5390-56002.fits
# 537: Loading 2 QSO spec. from plate: spPlate-5391-56000.fits
# 538: Loading 1 QSO spec. from plate: spPlate-5393-55946.fits
# 539: Loading 1 QSO spec. from plate: spPlate-5394-56001.fits
# 540: Loading 1 QSO spec. from plate: spPlate-5395-56003.fits
# 541: Loading 1 QSO spec. from plate: spPlate-5396-55947.fits
# 542: Loading 2 QSO spec. from plate: spPlate-5398-56011.fits
# 543: Loading 2 QSO spec. from plate: spPlate-5399-55956.fits
# 544: Loading 3 QSO spec. from plate: spPlate-5401-55949.fits
# 545: Loading 2 QSO spec. from plate: spPlate-5402-55927.fits
# 546: Loading 3 QSO spec. from plate: spPlate-5403-55979.fits
# 547: Loading 2 QSO spec. from plate: spPlate-5404-56013.fits
# 548: Loading 2 QSO spec. from plate: spPlate-5405-56010.fits
# 549: Loading 2 QSO spec. from plate: spPlate-5408-56038.fits
# 550: Loading 2 QSO spec. from plate: spPlate-5409-55957.fits
# 551: Loading 1 QSO spec. from plate: spPlate-5410-56016.fits
# 552: Loading 1 QSO spec. from plate: spPlate-5411-55953.fits
# 553: Loading 1 QSO spec. from plate: spPlate-5412-55981.fits
# 554: Loading 1 QSO spec. from plate: spPlate-5414-56014.fits
# 555: Loading 1 QSO spec. from plate: spPlate-5418-56037.fits
# 556: Loading 3 QSO spec. from plate: spPlate-5421-55980.fits
# 557: Loading 1 QSO spec. from plate: spPlate-5422-55986.fits
# 558: Loading 2 QSO spec. from plate: spPlate-5423-55958.fits
# 559: Loading 1 QSO spec. from plate: spPlate-5427-56001.fits
# 560: Loading 2 QSO spec. from plate: spPlate-5431-56011.fits
# 561: Loading 1 QSO spec. from plate: spPlate-5432-56008.fits
# 562: Loading 1 QSO spec. from plate: spPlate-5434-56033.fits
# 563: Loading 3 QSO spec. from plate: spPlate-5435-55982.fits
# 564: Loading 1 QSO spec. from plate: spPlate-5436-56015.fits
# 565: Loading 1 QSO spec. from plate: spPlate-5437-55973.fits
# 566: Loading 1 QSO spec. from plate: spPlate-5441-56017.fits
# 567: Loading 1 QSO spec. from plate: spPlate-5442-55978.fits
# 568: Loading 2 QSO spec. from plate: spPlate-5443-56010.fits
# 569: Loading 1 QSO spec. from plate: spPlate-5445-55987.fits
# 570: Loading 1 QSO spec. from plate: spPlate-5446-56014.fits
# 571: Loading 1 QSO spec. from plate: spPlate-5447-55958.fits
# 572: Loading 1 QSO spec. from plate: spPlate-5448-56013.fits
# 573: Loading 3 QSO spec. from plate: spPlate-5451-56010.fits
# 574: Loading 3 QSO spec. from plate: spPlate-5452-55957.fits
# 575: Loading 2 QSO spec. from plate: spPlate-5453-56001.fits
# 576: Loading 1 QSO spec. from plate: spPlate-5454-56015.fits
# 577: Loading 1 QSO spec. from plate: spPlate-5455-56009.fits
# 578: Loading 3 QSO spec. from plate: spPlate-5456-55980.fits
# 579: Loading 1 QSO spec. from plate: spPlate-5458-56011.fits
# 580: Loading 3 QSO spec. from plate: spPlate-5459-56035.fits
# 581: Loading 2 QSO spec. from plate: spPlate-5460-56000.fits
# 582: Loading 2 QSO spec. from plate: spPlate-5461-56018.fits
# 583: Loading 3 QSO spec. from plate: spPlate-5464-56035.fits
# 584: Loading 1 QSO spec. from plate: spPlate-5466-56033.fits
# 585: Loading 1 QSO spec. from plate: spPlate-5470-56008.fits
# 586: Loading 2 QSO spec. from plate: spPlate-5471-56034.fits
# 587: Loading 1 QSO spec. from plate: spPlate-5472-55976.fits
# 588: Loading 4 QSO spec. from plate: spPlate-5473-56033.fits
# 589: Loading 3 QSO spec. from plate: spPlate-5474-56036.fits
# 590: Loading 2 QSO spec. from plate: spPlate-5475-56011.fits
# 591: Loading 1 QSO spec. from plate: spPlate-5476-55986.fits
# 592: Loading 1 QSO spec. from plate: spPlate-5479-56016.fits
# 593: Loading 1 QSO spec. from plate: spPlate-5482-56017.fits
# 594: Loading 1 QSO spec. from plate: spPlate-5484-56039.fits
# 595: Loading 5 QSO spec. from plate: spPlate-5485-56063.fits
# 596: Loading 1 QSO spec. from plate: spPlate-5486-56030.fits
# 597: Loading 1 QSO spec. from plate: spPlate-5487-55982.fits
# 598: Loading 1 QSO spec. from plate: spPlate-5489-55990.fits
# 599: Loading 3 QSO spec. from plate: spPlate-5491-56034.fits
# 600: Loading 2 QSO spec. from plate: spPlate-5493-56009.fits
# 601: Loading 1 QSO spec. from plate: spPlate-5494-55857.fits
# 602: Loading 1 QSO spec. from plate: spPlate-5648-55923.fits
# 603: Loading 1 QSO spec. from plate: spPlate-5694-56213.fits
# 604: Loading 1 QSO spec. from plate: spPlate-5697-55944.fits
# 605: Loading 2 QSO spec. from plate: spPlate-5699-55953.fits
# 606: Loading 1 QSO spec. from plate: spPlate-5701-55949.fits
# 607: Loading 2 QSO spec. from plate: spPlate-5707-56269.fits
# 608: Loading 1 QSO spec. from plate: spPlate-5708-56605.fits
# 609: Loading 2 QSO spec. from plate: spPlate-5709-56571.fits
# 610: Loading 1 QSO spec. from plate: spPlate-5712-56602.fits
# 611: Loading 2 QSO spec. from plate: spPlate-5715-56657.fits
# 612: Loading 1 QSO spec. from plate: spPlate-5716-56684.fits
# 613: Loading 2 QSO spec. from plate: spPlate-5719-56014.fits
# 614: Loading 1 QSO spec. from plate: spPlate-5722-56008.fits
# 615: Loading 1 QSO spec. from plate: spPlate-5724-56364.fits
# 616: Loading 1 QSO spec. from plate: spPlate-5729-56598.fits
# 617: Loading 1 QSO spec. from plate: spPlate-5730-56607.fits
# 618: Loading 2 QSO spec. from plate: spPlate-5735-55980.fits
# 619: Loading 2 QSO spec. from plate: spPlate-5766-56248.fits
# 620: Loading 1 QSO spec. from plate: spPlate-5767-56245.fits
# 621: Loading 1 QSO spec. from plate: spPlate-5768-56017.fits
# 622: Loading 1 QSO spec. from plate: spPlate-5771-56011.fits
# 623: Loading 3 QSO spec. from plate: spPlate-5772-56003.fits
# 624: Loading 1 QSO spec. from plate: spPlate-5773-56009.fits
# 625: Loading 2 QSO spec. from plate: spPlate-5775-56009.fits
# 626: Loading 1 QSO spec. from plate: spPlate-5776-56010.fits
# 627: Loading 3 QSO spec. from plate: spPlate-5777-56280.fits
# 628: Loading 1 QSO spec. from plate: spPlate-5778-56328.fits
# 629: Loading 3 QSO spec. from plate: spPlate-5779-56338.fits
# 630: Loading 1 QSO spec. from plate: spPlate-5780-56274.fits
# 631: Loading 1 QSO spec. from plate: spPlate-5781-56337.fits
# 632: Loading 2 QSO spec. from plate: spPlate-5783-56017.fits
# 633: Loading 1 QSO spec. from plate: spPlate-5784-56029.fits
# 634: Loading 2 QSO spec. from plate: spPlate-5785-56269.fits
# 635: Loading 4 QSO spec. from plate: spPlate-5786-56251.fits
# 636: Loading 1 QSO spec. from plate: spPlate-5788-56255.fits
# 637: Loading 1 QSO spec. from plate: spPlate-5789-56246.fits
# 638: Loading 1 QSO spec. from plate: spPlate-5790-56271.fits
# 639: Loading 1 QSO spec. from plate: spPlate-5791-56255.fits
# 640: Loading 3 QSO spec. from plate: spPlate-5792-56269.fits
# 641: Loading 1 QSO spec. from plate: spPlate-5793-56337.fits
# 642: Loading 1 QSO spec. from plate: spPlate-5796-56274.fits
# 643: Loading 3 QSO spec. from plate: spPlate-5799-56325.fits
# 644: Loading 1 QSO spec. from plate: spPlate-5800-56279.fits
# 645: Loading 2 QSO spec. from plate: spPlate-5801-56328.fits
# 646: Loading 2 QSO spec. from plate: spPlate-5802-56309.fits
# 647: Loading 1 QSO spec. from plate: spPlate-5805-56336.fits
# 648: Loading 1 QSO spec. from plate: spPlate-5809-56353.fits
# 649: Loading 2 QSO spec. from plate: spPlate-5810-56358.fits
# 650: Loading 5 QSO spec. from plate: spPlate-5811-56334.fits
# 651: Loading 1 QSO spec. from plate: spPlate-5812-56354.fits
# 652: Loading 1 QSO spec. from plate: spPlate-5847-56037.fits
# 653: Loading 1 QSO spec. from plate: spPlate-5851-56075.fits
# 654: Loading 1 QSO spec. from plate: spPlate-5856-56090.fits
# 655: Loading 1 QSO spec. from plate: spPlate-5859-56065.fits
# 656: Loading 1 QSO spec. from plate: spPlate-5860-56046.fits
# 657: Loading 1 QSO spec. from plate: spPlate-5861-56069.fits
# 658: Loading 2 QSO spec. from plate: spPlate-5862-56045.fits
# 659: Loading 3 QSO spec. from plate: spPlate-5863-56042.fits
# 660: Loading 1 QSO spec. from plate: spPlate-5864-56047.fits
# 661: Loading 2 QSO spec. from plate: spPlate-5865-56067.fits
# 662: Loading 1 QSO spec. from plate: spPlate-5866-56035.fits
# 663: Loading 1 QSO spec. from plate: spPlate-5870-56065.fits
# 664: Loading 2 QSO spec. from plate: spPlate-5871-56041.fits
# 665: Loading 1 QSO spec. from plate: spPlate-5872-56027.fits
# 666: Loading 1 QSO spec. from plate: spPlate-5875-56038.fits
# 667: Loading 2 QSO spec. from plate: spPlate-5876-56042.fits
# 668: Loading 1 QSO spec. from plate: spPlate-5877-56041.fits
# 669: Loading 2 QSO spec. from plate: spPlate-5878-56033.fits
# 670: Loading 1 QSO spec. from plate: spPlate-5879-56047.fits
# 671: Loading 2 QSO spec. from plate: spPlate-5881-56038.fits
# 672: Loading 1 QSO spec. from plate: spPlate-5883-56033.fits
# 673: Loading 2 QSO spec. from plate: spPlate-5885-56036.fits
# 674: Loading 1 QSO spec. from plate: spPlate-5887-56035.fits
# 675: Loading 1 QSO spec. from plate: spPlate-5889-56038.fits
# 676: Loading 1 QSO spec. from plate: spPlate-5892-56035.fits
# 677: Loading 3 QSO spec. from plate: spPlate-5894-56039.fits
# 678: Loading 1 QSO spec. from plate: spPlate-5897-56042.fits
# 679: Loading 1 QSO spec. from plate: spPlate-5899-56038.fits
# 680: Loading 1 QSO spec. from plate: spPlate-5901-56039.fits
# 681: Loading 4 QSO spec. from plate: spPlate-5903-56064.fits
# 682: Loading 1 QSO spec. from plate: spPlate-5905-56065.fits
# 683: Loading 1 QSO spec. from plate: spPlate-5949-56096.fits
# 684: Loading 1 QSO spec. from plate: spPlate-5952-56453.fits
# 685: Loading 1 QSO spec. from plate: spPlate-5953-56092.fits
# 686: Loading 1 QSO spec. from plate: spPlate-5954-56462.fits
# 687: Loading 2 QSO spec. from plate: spPlate-5957-56210.fits
# 688: Loading 1 QSO spec. from plate: spPlate-5959-56214.fits
# 689: Loading 1 QSO spec. from plate: spPlate-5966-56101.fits
# 690: Loading 2 QSO spec. from plate: spPlate-5968-56356.fits
# 691: Loading 1 QSO spec. from plate: spPlate-5969-56069.fits
# 692: Loading 1 QSO spec. from plate: spPlate-5970-56072.fits
# 693: Loading 1 QSO spec. from plate: spPlate-5971-56064.fits
# 694: Loading 1 QSO spec. from plate: spPlate-5972-56334.fits
# 695: Loading 1 QSO spec. from plate: spPlate-5974-56314.fits
# 696: Loading 3 QSO spec. from plate: spPlate-5975-56334.fits
# 697: Loading 1 QSO spec. from plate: spPlate-5976-56356.fits
# 698: Loading 3 QSO spec. from plate: spPlate-5977-56098.fits
# 699: Loading 1 QSO spec. from plate: spPlate-5978-56073.fits
# 700: Loading 1 QSO spec. from plate: spPlate-5979-56329.fits
# 701: Loading 2 QSO spec. from plate: spPlate-5981-56340.fits
# 702: Loading 2 QSO spec. from plate: spPlate-5982-56074.fits
# 703: Loading 1 QSO spec. from plate: spPlate-5983-56310.fits
# 704: Loading 1 QSO spec. from plate: spPlate-5984-56337.fits
# 705: Loading 2 QSO spec. from plate: spPlate-5988-56072.fits
# 706: Loading 1 QSO spec. from plate: spPlate-5989-56312.fits
# 707: Loading 1 QSO spec. from plate: spPlate-5993-56070.fits
# 708: Loading 1 QSO spec. from plate: spPlate-5994-56101.fits
# 709: Loading 2 QSO spec. from plate: spPlate-5998-56087.fits
# 710: Loading 2 QSO spec. from plate: spPlate-5999-56089.fits
# 711: Loading 3 QSO spec. from plate: spPlate-6000-56102.fits
# 712: Loading 1 QSO spec. from plate: spPlate-6001-56072.fits
# 713: Loading 2 QSO spec. from plate: spPlate-6002-56104.fits
# 714: Loading 2 QSO spec. from plate: spPlate-6004-56066.fits
# 715: Loading 3 QSO spec. from plate: spPlate-6007-56066.fits
# 716: Loading 2 QSO spec. from plate: spPlate-6008-56093.fits
# 717: Loading 1 QSO spec. from plate: spPlate-6009-56313.fits
# 718: Loading 1 QSO spec. from plate: spPlate-6012-56101.fits
# 719: Loading 1 QSO spec. from plate: spPlate-6014-56072.fits
# 720: Loading 1 QSO spec. from plate: spPlate-6015-56096.fits
# 721: Loading 1 QSO spec. from plate: spPlate-6017-56075.fits
# 722: Loading 1 QSO spec. from plate: spPlate-6018-56067.fits
# 723: Loading 1 QSO spec. from plate: spPlate-6019-56074.fits
# 724: Loading 2 QSO spec. from plate: spPlate-6022-56076.fits
# 725: Loading 1 QSO spec. from plate: spPlate-6023-56069.fits
# 726: Loading 1 QSO spec. from plate: spPlate-6024-56088.fits
# 727: Loading 1 QSO spec. from plate: spPlate-6026-56071.fits
# 728: Loading 1 QSO spec. from plate: spPlate-6030-56097.fits
# 729: Loading 1 QSO spec. from plate: spPlate-6031-56091.fits
# 730: Loading 3 QSO spec. from plate: spPlate-6034-56103.fits
# 731: Loading 2 QSO spec. from plate: spPlate-6035-56076.fits
# 732: Loading 1 QSO spec. from plate: spPlate-6036-56093.fits
# 733: Loading 2 QSO spec. from plate: spPlate-6037-56104.fits
# 734: Loading 2 QSO spec. from plate: spPlate-6037-56106.fits
# 735: Loading 1 QSO spec. from plate: spPlate-6038-56090.fits
# 736: Loading 1 QSO spec. from plate: spPlate-6039-56099.fits
# 737: Loading 1 QSO spec. from plate: spPlate-6040-56101.fits
# 738: Loading 1 QSO spec. from plate: spPlate-6042-56101.fits
# 739: Loading 1 QSO spec. from plate: spPlate-6045-56072.fits
# 740: Loading 2 QSO spec. from plate: spPlate-6048-56072.fits
# 741: Loading 1 QSO spec. from plate: spPlate-6049-56091.fits
# 742: Loading 1 QSO spec. from plate: spPlate-6052-56092.fits
# 743: Loading 1 QSO spec. from plate: spPlate-6055-56102.fits
# 744: Loading 1 QSO spec. from plate: spPlate-6057-56099.fits
# 745: Loading 3 QSO spec. from plate: spPlate-6058-56090.fits
# 746: Loading 1 QSO spec. from plate: spPlate-6059-56093.fits
# 747: Loading 1 QSO spec. from plate: spPlate-6061-56076.fits
# 748: Loading 1 QSO spec. from plate: spPlate-6062-56091.fits
# 749: Loading 2 QSO spec. from plate: spPlate-6110-56279.fits
# 750: Loading 3 QSO spec. from plate: spPlate-6112-56191.fits
# 751: Loading 1 QSO spec. from plate: spPlate-6114-56209.fits
# 752: Loading 1 QSO spec. from plate: spPlate-6122-56246.fits
# 753: Loading 1 QSO spec. from plate: spPlate-6123-56217.fits
# 754: Loading 1 QSO spec. from plate: spPlate-6126-56269.fits
# 755: Loading 2 QSO spec. from plate: spPlate-6133-56246.fits
# 756: Loading 1 QSO spec. from plate: spPlate-6137-56270.fits
# 757: Loading 1 QSO spec. from plate: spPlate-6138-56598.fits
# 758: Loading 1 QSO spec. from plate: spPlate-6140-56189.fits
# 759: Loading 1 QSO spec. from plate: spPlate-6141-56210.fits
# 760: Loading 1 QSO spec. from plate: spPlate-6143-56267.fits
# 761: Loading 1 QSO spec. from plate: spPlate-6144-56237.fits
# 762: Loading 3 QSO spec. from plate: spPlate-6145-56266.fits
# 763: Loading 1 QSO spec. from plate: spPlate-6146-56265.fits
# 764: Loading 2 QSO spec. from plate: spPlate-6148-56209.fits
# 765: Loading 2 QSO spec. from plate: spPlate-6151-56265.fits
# 766: Loading 1 QSO spec. from plate: spPlate-6157-56238.fits
# 767: Loading 1 QSO spec. from plate: spPlate-6158-56239.fits
# 768: Loading 1 QSO spec. from plate: spPlate-6159-56214.fits
# 769: Loading 1 QSO spec. from plate: spPlate-6161-56238.fits
# 770: Loading 2 QSO spec. from plate: spPlate-6162-56191.fits
# 771: Loading 2 QSO spec. from plate: spPlate-6163-56219.fits
# 772: Loading 2 QSO spec. from plate: spPlate-6164-56181.fits
# 773: Loading 1 QSO spec. from plate: spPlate-6167-56189.fits
# 774: Loading 2 QSO spec. from plate: spPlate-6171-56311.fits
# 775: Loading 1 QSO spec. from plate: spPlate-6172-56269.fits
# 776: Loading 1 QSO spec. from plate: spPlate-6173-56238.fits
# 777: Loading 2 QSO spec. from plate: spPlate-6177-56268.fits
# 778: Loading 1 QSO spec. from plate: spPlate-6178-56213.fits
# 779: Loading 3 QSO spec. from plate: spPlate-6179-56221.fits
# 780: Loading 2 QSO spec. from plate: spPlate-6180-56301.fits
# 781: Loading 4 QSO spec. from plate: spPlate-6183-56210.fits
# ...
# 1056: Loading 1 QSO spec. from plate: spPlate-7137-56566.fits
# 1057: Loading 1 QSO spec. from plate: spPlate-7140-56569.fits
# 1058: Loading 1 QSO spec. from plate: spPlate-7141-56565.fits
# 1059: Loading 2 QSO spec. from plate: spPlate-7143-56572.fits
# 1060: Loading 2 QSO spec. from plate: spPlate-7144-56564.fits
# 1061: Loading 4 QSO spec. from plate: spPlate-7275-57093.fits
# 1062: Loading 1 QSO spec. from plate: spPlate-7276-57061.fits
# 1063: Loading 3 QSO spec. from plate: spPlate-7277-56748.fits
# 1064: Loading 2 QSO spec. from plate: spPlate-7278-57041.fits
# 1065: Loading 1 QSO spec. from plate: spPlate-7279-57071.fits
# 1066: Loading 1 QSO spec. from plate: spPlate-7280-56709.fits
# 1067: Loading 2 QSO spec. from plate: spPlate-7281-57007.fits
# 1068: Loading 2 QSO spec. from plate: spPlate-7282-56660.fits
# 1069: Loading 3 QSO spec. from plate: spPlate-7285-56991.fits
# 1070: Loading 1 QSO spec. from plate: spPlate-7286-57096.fits
# 1071: Loading 1 QSO spec. from plate: spPlate-7289-57039.fits
# 1072: Loading 1 QSO spec. from plate: spPlate-7290-57073.fits
# 1073: Loading 2 QSO spec. from plate: spPlate-7291-56992.fits
# 1074: Loading 1 QSO spec. from plate: spPlate-7293-56741.fits
# 1075: Loading 1 QSO spec. from plate: spPlate-7294-56739.fits
# 1076: Loading 1 QSO spec. from plate: spPlate-7296-57046.fits
# 1077: Loading 1 QSO spec. from plate: spPlate-7298-56661.fits
# 1078: Loading 2 QSO spec. from plate: spPlate-7304-56745.fits
# 1079: Loading 1 QSO spec. from plate: spPlate-7305-56991.fits
# 1080: Loading 1 QSO spec. from plate: spPlate-7306-56684.fits
# 1081: Loading 1 QSO spec. from plate: spPlate-7315-56685.fits
# 1082: Loading 4 QSO spec. from plate: spPlate-7316-56710.fits
# 1083: Loading 1 QSO spec. from plate: spPlate-7317-56992.fits
# 1084: Loading 1 QSO spec. from plate: spPlate-7324-56935.fits
# 1085: Loading 1 QSO spec. from plate: spPlate-7326-56710.fits
# 1086: Loading 1 QSO spec. from plate: spPlate-7327-56715.fits
# 1087: Loading 1 QSO spec. from plate: spPlate-7337-56662.fits
# 1088: Loading 2 QSO spec. from plate: spPlate-7339-56768.fits
# 1089: Loading 2 QSO spec. from plate: spPlate-7339-56772.fits
# 1090: Loading 2 QSO spec. from plate: spPlate-7381-56717.fits
# 1091: Loading 1 QSO spec. from plate: spPlate-7382-56991.fits
# 1092: Loading 1 QSO spec. from plate: spPlate-7384-56715.fits
# 1093: Loading 1 QSO spec. from plate: spPlate-7386-56769.fits
# 1094: Loading 1 QSO spec. from plate: spPlate-7388-56783.fits
# 1095: Loading 1 QSO spec. from plate: spPlate-7389-56769.fits
# 1096: Loading 1 QSO spec. from plate: spPlate-7392-56992.fits
# 1097: Loading 1 QSO spec. from plate: spPlate-7393-56749.fits
# 1098: Loading 1 QSO spec. from plate: spPlate-7394-57131.fits
# 1099: Loading 1 QSO spec. from plate: spPlate-7395-57131.fits
# 1100: Loading 2 QSO spec. from plate: spPlate-7396-56809.fits
# 1101: Loading 1 QSO spec. from plate: spPlate-7398-56781.fits
# 1102: Loading 1 QSO spec. from plate: spPlate-7401-56808.fits
# 1103: Loading 2 QSO spec. from plate: spPlate-7407-56772.fits
# 1104: Loading 1 QSO spec. from plate: spPlate-7408-56780.fits
# 1105: Loading 1 QSO spec. from plate: spPlate-7409-56809.fits
# 1106: Loading 2 QSO spec. from plate: spPlate-7410-57104.fits
# 1107: Loading 1 QSO spec. from plate: spPlate-7417-56753.fits
# 1108: Loading 1 QSO spec. from plate: spPlate-7418-57165.fits
# 1109: Loading 2 QSO spec. from plate: spPlate-7420-56753.fits
# 1110: Loading 1 QSO spec. from plate: spPlate-7421-57159.fits
# 1111: Loading 2 QSO spec. from plate: spPlate-7422-56799.fits
# 1112: Loading 1 QSO spec. from plate: spPlate-7423-57135.fits
# 1113: Loading 1 QSO spec. from plate: spPlate-7424-57160.fits
# 1114: Loading 1 QSO spec. from plate: spPlate-7429-56740.fits
# 1115: Loading 1 QSO spec. from plate: spPlate-7432-57107.fits
# 1116: Loading 2 QSO spec. from plate: spPlate-7445-56720.fits
# 1117: Loading 2 QSO spec. from plate: spPlate-7446-56722.fits
# 1118: Loading 1 QSO spec. from plate: spPlate-7447-56746.fits
# 1119: Loading 1 QSO spec. from plate: spPlate-7448-56739.fits
# 1120: Loading 2 QSO spec. from plate: spPlate-7512-56777.fits
# 1121: Loading 3 QSO spec. from plate: spPlate-7516-56782.fits
# 1122: Loading 1 QSO spec. from plate: spPlate-7517-56772.fits
# 1123: Loading 1 QSO spec. from plate: spPlate-7575-56947.fits
# 1124: Loading 1 QSO spec. from plate: spPlate-7576-56948.fits
# 1125: Loading 1 QSO spec. from plate: spPlate-7579-56954.fits
# 1126: Loading 1 QSO spec. from plate: spPlate-7581-57195.fits
# 1127: Loading 1 QSO spec. from plate: spPlate-7584-56957.fits
# 1128: Loading 1 QSO spec. from plate: spPlate-7585-57190.fits
# 1129: Loading 1 QSO spec. from plate: spPlate-7590-56944.fits
# 1130: Loading 2 QSO spec. from plate: spPlate-7591-56954.fits
# 1131: Loading 1 QSO spec. from plate: spPlate-7592-56947.fits
# 1132: Loading 3 QSO spec. from plate: spPlate-7596-56945.fits
# 1133: Loading 1 QSO spec. from plate: spPlate-7597-56973.fits
# 1134: Loading 3 QSO spec. from plate: spPlate-7599-56955.fits
# 1135: Loading 1 QSO spec. from plate: spPlate-7601-56959.fits
# 1136: Loading 2 QSO spec. from plate: spPlate-7602-56954.fits
# 1137: Loading 1 QSO spec. from plate: spPlate-7604-56947.fits
# 1138: Loading 1 QSO spec. from plate: spPlate-7605-56949.fits
# 1139: Loading 1 QSO spec. from plate: spPlate-7606-56977.fits
# 1140: Loading 1 QSO spec. from plate: spPlate-7607-56902.fits
# 1141: Loading 1 QSO spec. from plate: spPlate-7609-56959.fits
# 1142: Loading 2 QSO spec. from plate: spPlate-7610-56980.fits
# 1143: Loading 1 QSO spec. from plate: spPlate-7613-56988.fits
# 1144: Loading 2 QSO spec. from plate: spPlate-7614-57307.fits
# 1145: Loading 1 QSO spec. from plate: spPlate-7617-56949.fits
# 1146: Loading 1 QSO spec. from plate: spPlate-7618-56898.fits
# 1147: Loading 4 QSO spec. from plate: spPlate-7620-56904.fits
# 1148: Loading 1 QSO spec. from plate: spPlate-7621-56985.fits
# 1149: Loading 1 QSO spec. from plate: spPlate-7623-56901.fits
# 1150: Loading 1 QSO spec. from plate: spPlate-7625-57011.fits
# 1151: Loading 1 QSO spec. from plate: spPlate-7627-56933.fits
# 1152: Loading 1 QSO spec. from plate: spPlate-7629-56988.fits
# 1153: Loading 2 QSO spec. from plate: spPlate-7630-57006.fits
# 1154: Loading 1 QSO spec. from plate: spPlate-7631-57279.fits
# 1155: Loading 2 QSO spec. from plate: spPlate-7633-56931.fits
# 1156: Loading 1 QSO spec. from plate: spPlate-7634-56935.fits
# 1157: Loading 1 QSO spec. from plate: spPlate-7635-56979.fits
# 1158: Loading 1 QSO spec. from plate: spPlate-7638-56981.fits
# 1159: Loading 1 QSO spec. from plate: spPlate-7639-57297.fits
# 1160: Loading 2 QSO spec. from plate: spPlate-7640-57311.fits
# 1161: Loading 1 QSO spec. from plate: spPlate-7644-57327.fits
# 1162: Loading 1 QSO spec. from plate: spPlate-7648-57329.fits
# 1163: Loading 1 QSO spec. from plate: spPlate-7654-57330.fits
# 1164: Loading 1 QSO spec. from plate: spPlate-7655-57336.fits
# 1165: Loading 1 QSO spec. from plate: spPlate-7656-57338.fits
# 1166: Loading 1 QSO spec. from plate: spPlate-7657-57309.fits
# 1167: Loading 3 QSO spec. from plate: spPlate-7659-57060.fits
# 1168: Loading 1 QSO spec. from plate: spPlate-7660-57357.fits
# 1169: Loading 2 QSO spec. from plate: spPlate-7661-57286.fits
# 1170: Loading 1 QSO spec. from plate: spPlate-7663-57328.fits
# 1171: Loading 1 QSO spec. from plate: spPlate-7664-57367.fits
# 1172: Loading 2 QSO spec. from plate: spPlate-7666-57339.fits
# 1173: Loading 1 QSO spec. from plate: spPlate-7670-57328.fits
# 1174: Loading 1 QSO spec. from plate: spPlate-7671-57360.fits
# 1175: Loading 1 QSO spec. from plate: spPlate-7673-57329.fits
# 1176: Loading 1 QSO spec. from plate: spPlate-7678-57282.fits
# 1177: Loading 1 QSO spec. from plate: spPlate-7681-57042.fits
# 1178: Loading 1 QSO spec. from plate: spPlate-7685-57062.fits
# 1179: Loading 1 QSO spec. from plate: spPlate-7687-57007.fits
# 1180: Loading 1 QSO spec. from plate: spPlate-7690-57046.fits
# 1181: Loading 2 QSO spec. from plate: spPlate-7691-57360.fits
# 1182: Loading 1 QSO spec. from plate: spPlate-7692-57064.fits
# 1183: Loading 1 QSO spec. from plate: spPlate-7693-57361.fits
# 1184: Loading 1 QSO spec. from plate: spPlate-7701-57356.fits
# 1185: Loading 1 QSO spec. from plate: spPlate-7714-57363.fits
# 1186: Loading 1 QSO spec. from plate: spPlate-7715-57364.fits
# 1187: Loading 3 QSO spec. from plate: spPlate-7718-57362.fits
# 1188: Loading 1 QSO spec. from plate: spPlate-7820-56984.fits
# 1189: Loading 2 QSO spec. from plate: spPlate-7824-57282.fits
# 1190: Loading 1 QSO spec. from plate: spPlate-7827-57278.fits
# 1191: Loading 1 QSO spec. from plate: spPlate-7833-57286.fits
# 1192: Loading 1 QSO spec. from plate: spPlate-7836-57278.fits
# 1193: Loading 2 QSO spec. from plate: spPlate-7839-56900.fits
# 1194: Loading 1 QSO spec. from plate: spPlate-7848-56959.fits
# 1195: Loading 1 QSO spec. from plate: spPlate-7849-56980.fits
# 1196: Loading 3 QSO spec. from plate: spPlate-7854-56989.fits
# 1197: Loading 2 QSO spec. from plate: spPlate-7855-57011.fits
# 1198: Loading 1 QSO spec. from plate: spPlate-7857-57278.fits
# 1199: Loading 2 QSO spec. from plate: spPlate-7858-57281.fits
# 1200: Loading 1 QSO spec. from plate: spPlate-7860-57006.fits
# 1201: Loading 1 QSO spec. from plate: spPlate-7861-57281.fits
# 1202: Loading 1 QSO spec. from plate: spPlate-7862-56984.fits
# 1203: Loading 2 QSO spec. from plate: spPlate-7866-57002.fits
# 1204: Loading 2 QSO spec. from plate: spPlate-7870-57016.fits
# 1205: Loading 1 QSO spec. from plate: spPlate-7872-57279.fits
# 1206: Loading 3 QSO spec. from plate: spPlate-8054-57194.fits
# 1207: Loading 5 QSO spec. from plate: spPlate-8055-57187.fits
# 1208: Loading 1 QSO spec. from plate: spPlate-8056-57186.fits
# 1209: Loading 1 QSO spec. from plate: spPlate-8068-57185.fits
# 1210: Loading 1 QSO spec. from plate: spPlate-8164-57127.fits
# 1211: Loading 1 QSO spec. from plate: spPlate-8165-57374.fits
# 1212: Loading 1 QSO spec. from plate: spPlate-8166-57130.fits
# 1213: Loading 1 QSO spec. from plate: spPlate-8167-57071.fits
# 1214: Loading 1 QSO spec. from plate: spPlate-8170-57131.fits
# 1215: Loading 1 QSO spec. from plate: spPlate-8171-57135.fits
# 1216: Loading 3 QSO spec. from plate: spPlate-8172-57423.fits
# 1217: Loading 1 QSO spec. from plate: spPlate-8173-57375.fits
# 1218: Loading 1 QSO spec. from plate: spPlate-8174-57374.fits
# 1219: Loading 1 QSO spec. from plate: spPlate-8175-57039.fits
# 1220: Loading 1 QSO spec. from plate: spPlate-8176-57131.fits
# 1221: Loading 2 QSO spec. from plate: spPlate-8178-57428.fits
# 1222: Loading 1 QSO spec. from plate: spPlate-8179-57429.fits
# 1223: Loading 1 QSO spec. from plate: spPlate-8180-57345.fits
# 1224: Loading 3 QSO spec. from plate: spPlate-8182-56993.fits
# 1225: Loading 1 QSO spec. from plate: spPlate-8184-57426.fits
# 1226: Loading 1 QSO spec. from plate: spPlate-8186-57452.fits
# 1227: Loading 1 QSO spec. from plate: spPlate-8187-57423.fits
# 1228: Loading 1 QSO spec. from plate: spPlate-8190-57448.fits
# 1229: Loading 1 QSO spec. from plate: spPlate-8191-57390.fits
# 1230: Loading 2 QSO spec. from plate: spPlate-8194-57401.fits
# 1231: Loading 1 QSO spec. from plate: spPlate-8195-57391.fits
# 1232: Loading 1 QSO spec. from plate: spPlate-8196-57346.fits
# 1233: Loading 3 QSO spec. from plate: spPlate-8199-57428.fits
# 1234: Loading 2 QSO spec. from plate: spPlate-8206-57424.fits
# 1235: Loading 1 QSO spec. from plate: spPlate-8210-57426.fits
# 1236: Loading 1 QSO spec. from plate: spPlate-8211-57423.fits
# 1237: Loading 1 QSO spec. from plate: spPlate-8219-57429.fits
# 1238: Loading 1 QSO spec. from plate: spPlate-8223-57429.fits
# 1239: Loading 3 QSO spec. from plate: spPlate-8225-57375.fits
# 1240: Loading 1 QSO spec. from plate: spPlate-8226-57423.fits
# 1241: Loading 1 QSO spec. from plate: spPlate-8227-57427.fits
# 1242: Loading 1 QSO spec. from plate: spPlate-8228-57423.fits
# 1243: Loading 1 QSO spec. from plate: spPlate-8230-57430.fits
# 1244: Loading 4 QSO spec. from plate: spPlate-8278-56990.fits
# 1245: Loading 2 QSO spec. from plate: spPlate-8279-57063.fits
# 1246: Loading 1 QSO spec. from plate: spPlate-8280-57061.fits
# 1247: Loading 1 QSO spec. from plate: spPlate-8282-57041.fits
# 1248: Loading 1 QSO spec. from plate: spPlate-8283-57064.fits
# 1249: Loading 1 QSO spec. from plate: spPlate-8285-57048.fits
# 1250: Loading 1 QSO spec. from plate: spPlate-8287-57401.fits
# 1251: Loading 1 QSO spec. from plate: spPlate-8288-57419.fits
# 1252: Loading 1 QSO spec. from plate: spPlate-8290-57364.fits
# 1253: Loading 2 QSO spec. from plate: spPlate-8293-57361.fits
# 1254: Loading 3 QSO spec. from plate: spPlate-8294-57365.fits
# 1255: Loading 1 QSO spec. from plate: spPlate-8298-57390.fits
# 1256: Loading 1 QSO spec. from plate: spPlate-8306-57419.fits
# 1257: Loading 1 QSO spec. from plate: spPlate-8359-57449.fits
# 1258: Loading 1 QSO spec. from plate: spPlate-8365-57450.fits
# 1259: Loading 1 QSO spec. from plate: spPlate-8366-57432.fits
# 1260: Loading 1 QSO spec. from plate: spPlate-8367-57429.fits
# 1261: Loading 2 QSO spec. from plate: spPlate-8380-57520.fits
# 1262: Loading 1 QSO spec. from plate: spPlate-8382-57513.fits
# 1263: Loading 1 QSO spec. from plate: spPlate-8384-57513.fits
# 1264: Loading 3 QSO spec. from plate: spPlate-8386-57518.fits
# 1265: Loading 4 QSO spec. from plate: spPlate-8387-57483.fits
# 1266: Loading 1 QSO spec. from plate: spPlate-8388-57488.fits
# 1267: Loading 3 QSO spec. from plate: spPlate-8390-57485.fits
# 1268: Loading 1 QSO spec. from plate: spPlate-8391-57511.fits
# 1269: Loading 1 QSO spec. from plate: spPlate-8392-57483.fits
# 1270: Loading 2 QSO spec. from plate: spPlate-8397-57482.fits
# 1271: Loading 1 QSO spec. from plate: spPlate-8404-57481.fits
# 1272: Loading 1 QSO spec. from plate: spPlate-8406-57513.fits
# 1273: Loading 2 QSO spec. from plate: spPlate-8410-57481.fits
# 1274: Loading 2 QSO spec. from plate: spPlate-8433-57488.fits
# 1275: Loading 1 QSO spec. from plate: spPlate-8434-57484.fits
# 1276: Loading 1 QSO spec. from plate: spPlate-8490-57104.fits
# 1277: Loading 1 QSO spec. from plate: spPlate-8491-57488.fits
# 1278: Loading 1 QSO spec. from plate: spPlate-8494-57104.fits
# 1279: Loading 2 QSO spec. from plate: spPlate-8495-57481.fits
# 1280: Loading 3 QSO spec. from plate: spPlate-8500-57432.fits
# 1281: Loading 2 QSO spec. from plate: spPlate-8501-57519.fits
# 1282: Loading 1 QSO spec. from plate: spPlate-8502-57512.fits
# 1283: Loading 1 QSO spec. from plate: spPlate-8504-57518.fits
# 1284: Loading 1 QSO spec. from plate: spPlate-8732-57418.fits
# 1285: Loading 1 QSO spec. from plate: spPlate-8740-57367.fits
# 1286: Loading 1 QSO spec. from plate: spPlate-8747-57401.fits
# 1287: Loading 1 QSO spec. from plate: spPlate-8819-57450.fits
# 1288: Loading 1 QSO spec. from plate: spPlate-8820-57449.fits
# 1289: Loading 2 QSO spec. from plate: spPlate-8823-57446.fits
# 1290: Loading 1 QSO spec. from plate: spPlate-8825-57451.fits
# 1291: Loading 2 QSO spec. from plate: spPlate-8826-57452.fits
# 1292: Loading 1 QSO spec. from plate: spPlate-8827-57444.fits
# 1293: Loading 1 QSO spec. from plate: spPlate-8830-57447.fits
# 1294: Loading 2 QSO spec. from plate: spPlate-8831-57448.fits
# 1295: Loading 1 QSO spec. from plate: spPlate-8832-57445.fits
# 1296: Loading 1 QSO spec. from plate: spPlate-8834-57458.fits
# 1297: Loading 1 QSO spec. from plate: spPlate-8836-57424.fits
# 1298: Loading 1 QSO spec. from plate: spPlate-8843-57423.fits
# 1299: Loading 1 QSO spec. from plate: spPlate-8849-57457.fits
# 1300: Loading 1 QSO spec. from plate: spPlate-8851-57460.fits
# 1301: Loading 2 QSO spec. from plate: spPlate-8853-57459.fits
# 1302: Loading 1 QSO spec. from plate: spPlate-8854-57450.fits
# 1303: Loading 3 QSO spec. from plate: spPlate-8856-57453.fits
# 1304: Loading 2 QSO spec. from plate: spPlate-8857-57449.fits
# 1305: Loading 1 QSO spec. from plate: spPlate-8858-57450.fits
# 1306: Loading 1 QSO spec. from plate: spPlate-8864-57428.fits
# 1307: Loading 1 QSO spec. from plate: spPlate-8865-57426.fits
# 1308: Loading 2 QSO spec. from plate: spPlate-8866-57457.fits
# 1309: Loading 1 QSO spec. from plate: spPlate-8869-57481.fits
# 1310: Loading 1 QSO spec. from plate: spPlate-8872-57422.fits
# 1311: Loading 1 QSO spec. from plate: spPlate-8873-57427.fits
# 1312: Loading 1 QSO spec. from plate: spPlate-8874-57426.fits
# Reading done.

# %%
def chi2( alpha, *args ):
   a,b = alpha
   w,flux,ivar = args
   return np.sum( (( flux - (a*w+b) )**2 ) * ivar )

# %%
#####################################
# Load QSO from plates     Desi
### Parameters
path_spec      = '/work3/desi_lya/mocks_quick/london/v9.0.0_small/spectra-16'
path_zcat      = '/home/sfbeltranv/respaldo/DR14_mini/zcat_m.fits'

# for line correction (later)
#path_lines     = '/work3/desi_lya/data/eBOSS/dr12_all/dr16-line-sky-mask.txt'

zmin = 2
zmax = 4

catalog = Table.read(path_zcat)


file = '/work3/desi_lya/mocks_quick/london/v9.0.0_small/spectra-16/10/1005/spectra-16-1005.fits' 
spec = Table.read( file )
#spec

h = pyfits.open( file )

h[0].header[4]

spectra_base= desispec.io.read_spectra( file )

spectra_base.__dict__
spectra_base.fibermap.__dict__
spectra_base.fibermap['TARGETID']

#spectra_base.meta
#spectra_base.meta['HPXPIXEL']

catalog['TARGETID']
# Out:
# <Column name='TARGETID' dtype='int64' length=10000>
#  60168679
#  80165406
#     42417
#  70133197
#  60182452
#  50255050
#  20110721
#  20061421
#  80355876
#  30227575
#  80319031
#  30131225
#       ...
#  80144073
# 300010421
#  30170885
#  70151476
#  30138735
#  50183793
#  30193911
#  80216791
#  70238724
#  30205578
#  50234390
#  50187539

# %%
def splitID(fi_str):
   fi_str= fi_str.split("spectra-16-")[1]
   return fi_str.split(".fits")[0]


def load_Desi(path_zcat, path_spec, zmin, zmax, lmin, lmax):
   # Desi Catalog load, beginning of function
   catalog = Table.read(path_zcat)
   qso_string = catalog['SPECTYPE'][0]
   
   #w = (catalog['SPECTYPE']==qso_string ) & (catalog['Z'] > zmin ) & (catalog['Z']< zmax ) & (catalog['RA']!=catalog['DEC'])& (catalog['RA']>0) & (catalog['DEC']>0)
   w = (catalog['SPECTYPE']==qso_string ) & (catalog['Z'] >= zmin ) & (catalog['Z'] <= zmax ) 
   reduced_cat = catalog[w]

   nest = True
   in_nside = 16

   targetid = reduced_cat['TARGETID']
   zqso = reduced_cat['Z']
   DEC = reduced_cat['DEC'] * np.pi/180
   RA = reduced_cat['RA'] * np.pi/180

   heal_pix = healpy.ang2pix(in_nside, sp.pi/2.-DEC, RA, nest)
   plate_list = np.unique(heal_pix)
   
   print( len( reduced_cat ) )
   print('healpix len: ', len(plate_list), 'healpix values: ',  plate_list )
   fi = glob.glob(path_spec+'/*/*/spectra*.fits*')
   print('Found', len(fi), 'spectra files.\n')
   fi_fix = []
   for i in range( 0, len(fi)):
       fi_fix.append( splitID(fi[i]) )

   fi_fix =  np.array( list(map(int, fi_fix)) ) 
   
   print('Found '+ str(  np.sum(w) ) + ' QSO spec. in ' + str( len(plate_list) ) + ' files.' )
   
   spectra = []
   QSOloc = []
   
   ## begin for test
   for nplate in range( 0, len(plate_list) ):      # len(plate_list)
      thisplate = plate_list[ nplate ]
      wp = heal_pix == int( thisplate )
      
      ids_ = targetid[wp]
      zqso_= zqso[wp]
      DEC_ = DEC[wp]
      RA_ = RA[wp]
      heal_pix_ = heal_pix[wp]
      
      # heal_pix: From healpy.ang2pix
      # plate_list: Unique from healpy.ang2pix \n
      # fi_fix: Plate id from directory list
      # fi: All files from glob
      nqsoPlate_= ids_.shape[0]
      # print( str(nplate) + ': Loading '+ str(nqsoPlate_) +' QSO spec. from file: '+ [] )      
      wpf = fi_fix == thisplate
      index = wpf * np.arange( len(fi_fix) )
      index = np.squeeze( index[wpf] )
      
      
      #print( thisplate,  nqsoPlate_ , len(fi_fix) )
      
      # print( thisplate, fi_fix[index], nqsoPlate_, fi[index] )
      print( str(nplate) + ': Loading '+ str(nqsoPlate_) +' QSO spec. from file: '+  str(thisplate) )
      
      spectra_base = desispec.io.read_spectra( fi[index] )   
      
      joint1 = np.in1d( spectra_base.wave['b'], spectra_base.wave['r'])
      joint2 = np.in1d( spectra_base.wave['r'], spectra_base.wave['b'])
            
      ll = np.concatenate( ( spectra_base.wave['b'][np.invert(joint1)] , spectra_base.wave['r'] ) )
      
      for i in range(0,nqsoPlate_):
         
         index = np.where( np.array( spectra_base.fibermap['TARGETID'].data ) == ids_.data[i] )
         index = np.squeeze(index)
         
         w_ = (ll)/(1+zqso_[ i ])
         w_crop = ( w_ >= lmin ) & ( w_ <= lmax )
         w_ = w_[w_crop] 
         
         intersec = ( spectra_base.ivar['b'][ index ][joint1]*spectra_base.flux['b'][ index ][joint1] + spectra_base.ivar['r'][ index ][joint2]*spectra_base.flux['r'][ index ][joint2] )
         intersec = intersec /( spectra_base.ivar['b'][ index ][joint1] + spectra_base.ivar['r'][ index ][joint2] )

         flx = np.concatenate( ( spectra_base.flux['b'][ index ][np.invert(joint1)], intersec, \
               spectra_base.flux['r'][ index ][np.invert(joint2)] ) )
         flx = flx[w_crop]
         
         intersec = ( spectra_base.ivar['b'][ index ][joint1] + spectra_base.ivar['r'][ index ][joint2] ) 
         ivr = np.concatenate( ( spectra_base.ivar['b'][ index ][np.invert(joint1)], intersec, \
               spectra_base.ivar['r'][ index ][np.invert(joint2)] ) )
         ivr = ivr[w_crop]
         
         flx = normalizeSpec( w_, flx, 1300, 1500)
         #flx = normalizeSpec( w_, flx, 1300, 1500)

         
         QSOloc.append( np.hstack(( zqso_[i], DEC_[i], RA_[i], ids_[i] )) ) 
         s=np.vstack( ( w_.conj().transpose(), flx.conj().transpose(), ivr.conj().transpose() ) )
         spectra.append( s )
   
   print('Reading done.')
   return QSOloc, spectra


path_zcat = '/home/sfbeltranv/respaldo/DR14_mini/zcat_m.fits' 
path_spec = '/work3/desi_lya/mocks_quick/london/v9.0.0_small/spectra-16'

zmin = 2.
zmax = 4.288461538461538

lmin = 1040
lmax = 1600

QSOloc_Desi, spectra_Desi = load_Desi(path_zcat, path_spec, zmin, zmax, lmin, lmax)
# Out:
# 7624
# healpix len:  164 healpix values:  DEC
# ----
#    0
#    1
#    2
#    3
#    8
#    9
#   10
#   11
#   12
#   14
#  ...
# 1159
# 1160
# 1161
# 1162
# 1163
# 1164
# 1165
# 1166
# 1167
# 1168
# 1169
# Length = 164 rows
# Found 167 spectra files.
#
# Found 7624 QSO spec. in 164 files.
# 0: Loading 71 QSO spec. from file: 0
# 1: Loading 24 QSO spec. from file: 1
# 2: Loading 60 QSO spec. from file: 2
# 3: Loading 14 QSO spec. from file: 3
# 4: Loading 50 QSO spec. from file: 8
# 5: Loading 26 QSO spec. from file: 9
# 6: Loading 51 QSO spec. from file: 10
# 7: Loading 52 QSO spec. from file: 11
# 8: Loading 1 QSO spec. from file: 12
# 9: Loading 30 QSO spec. from file: 14
# 10: Loading 60 QSO spec. from file: 32
# 11: Loading 51 QSO spec. from file: 33
# 12: Loading 49 QSO spec. from file: 34
# 13: Loading 41 QSO spec. from file: 35
# 14: Loading 53 QSO spec. from file: 36
# 15: Loading 27 QSO spec. from file: 37
# 16: Loading 55 QSO spec. from file: 38
# 17: Loading 49 QSO spec. from file: 39
# 18: Loading 43 QSO spec. from file: 40
# 19: Loading 41 QSO spec. from file: 41
# 20: Loading 42 QSO spec. from file: 42
# 21: Loading 40 QSO spec. from file: 43
# 22: Loading 51 QSO spec. from file: 44
# 23: Loading 54 QSO spec. from file: 45
# 24: Loading 55 QSO spec. from file: 46
# 25: Loading 56 QSO spec. from file: 47
# 26: Loading 6 QSO spec. from file: 50
# 27: Loading 46 QSO spec. from file: 56
# 28: Loading 34 QSO spec. from file: 58
# 29: Loading 70 QSO spec. from file: 128
# 30: Loading 42 QSO spec. from file: 129
# 31: Loading 50 QSO spec. from file: 130
# 32: Loading 54 QSO spec. from file: 131
# 33: Loading 44 QSO spec. from file: 132
# 34: Loading 48 QSO spec. from file: 133
# 35: Loading 52 QSO spec. from file: 134
# 36: Loading 39 QSO spec. from file: 135
# 37: Loading 47 QSO spec. from file: 136
# 38: Loading 49 QSO spec. from file: 137
# 39: Loading 38 QSO spec. from file: 138
# 40: Loading 47 QSO spec. from file: 139
# 41: Loading 47 QSO spec. from file: 140
# 42: Loading 7 QSO spec. from file: 141
# 43: Loading 14 QSO spec. from file: 142
# 44: Loading 43 QSO spec. from file: 144
# 45: Loading 1 QSO spec. from file: 146
# 46: Loading 49 QSO spec. from file: 160
# 47: Loading 11 QSO spec. from file: 161
# 48: Loading 10 QSO spec. from file: 162
# 49: Loading 60 QSO spec. from file: 1000
# 50: Loading 58 QSO spec. from file: 1001
# 51: Loading 48 QSO spec. from file: 1002
# 52: Loading 44 QSO spec. from file: 1003
# 53: Loading 34 QSO spec. from file: 1004
# 54: Loading 1 QSO spec. from file: 1005
# 55: Loading 46 QSO spec. from file: 1006
# 56: Loading 24 QSO spec. from file: 1007
# 57: Loading 1 QSO spec. from file: 1044
# 58: Loading 22 QSO spec. from file: 1045
# 59: Loading 30 QSO spec. from file: 1046
# 60: Loading 46 QSO spec. from file: 1047
# 61: Loading 43 QSO spec. from file: 1052
# 62: Loading 44 QSO spec. from file: 1053
# 63: Loading 35 QSO spec. from file: 1054
# 64: Loading 57 QSO spec. from file: 1055
# 65: Loading 33 QSO spec. from file: 1069
# 66: Loading 30 QSO spec. from file: 1070
# 67: Loading 56 QSO spec. from file: 1071
# 68: Loading 31 QSO spec. from file: 1073
# 69: Loading 37 QSO spec. from file: 1074
# 70: Loading 61 QSO spec. from file: 1075
# 71: Loading 48 QSO spec. from file: 1076
# 72: Loading 60 QSO spec. from file: 1077
# 73: Loading 58 QSO spec. from file: 1078
# 74: Loading 51 QSO spec. from file: 1079
# 75: Loading 48 QSO spec. from file: 1080
# 76: Loading 55 QSO spec. from file: 1081
# 77: Loading 52 QSO spec. from file: 1082
# 78: Loading 58 QSO spec. from file: 1083
# 79: Loading 50 QSO spec. from file: 1084
# 80: Loading 43 QSO spec. from file: 1085
# 81: Loading 49 QSO spec. from file: 1086
# 82: Loading 55 QSO spec. from file: 1087
# 83: Loading 54 QSO spec. from file: 1088
# 84: Loading 57 QSO spec. from file: 1089
# 85: Loading 59 QSO spec. from file: 1090
# 86: Loading 58 QSO spec. from file: 1091
# 87: Loading 49 QSO spec. from file: 1092
# 88: Loading 43 QSO spec. from file: 1093
# 89: Loading 43 QSO spec. from file: 1094
# 90: Loading 68 QSO spec. from file: 1095
# 91: Loading 51 QSO spec. from file: 1096
# 92: Loading 49 QSO spec. from file: 1097
# 93: Loading 55 QSO spec. from file: 1098
# 94: Loading 48 QSO spec. from file: 1099
# 95: Loading 54 QSO spec. from file: 1100
# 96: Loading 42 QSO spec. from file: 1101
# 97: Loading 57 QSO spec. from file: 1102
# 98: Loading 45 QSO spec. from file: 1103
# 99: Loading 60 QSO spec. from file: 1104
# 100: Loading 52 QSO spec. from file: 1105
# 101: Loading 44 QSO spec. from file: 1106
# 102: Loading 47 QSO spec. from file: 1107
# 103: Loading 52 QSO spec. from file: 1108
# 104: Loading 58 QSO spec. from file: 1109
# 105: Loading 51 QSO spec. from file: 1110
# 106: Loading 48 QSO spec. from file: 1111
# 107: Loading 56 QSO spec. from file: 1112
# 108: Loading 51 QSO spec. from file: 1113
# 109: Loading 45 QSO spec. from file: 1114
# 110: Loading 65 QSO spec. from file: 1115
# 111: Loading 72 QSO spec. from file: 1116
# 112: Loading 49 QSO spec. from file: 1117
# 113: Loading 53 QSO spec. from file: 1118
# 114: Loading 49 QSO spec. from file: 1119
# 115: Loading 47 QSO spec. from file: 1120
# 116: Loading 45 QSO spec. from file: 1121
# 117: Loading 61 QSO spec. from file: 1122
# 118: Loading 57 QSO spec. from file: 1123
# 119: Loading 48 QSO spec. from file: 1124
# 120: Loading 66 QSO spec. from file: 1125
# 121: Loading 51 QSO spec. from file: 1126
# 122: Loading 55 QSO spec. from file: 1127
# 123: Loading 41 QSO spec. from file: 1128
# 124: Loading 52 QSO spec. from file: 1129
# 125: Loading 47 QSO spec. from file: 1130
# 126: Loading 55 QSO spec. from file: 1131
# 127: Loading 63 QSO spec. from file: 1132
# 128: Loading 52 QSO spec. from file: 1133
# 129: Loading 45 QSO spec. from file: 1134
# 130: Loading 48 QSO spec. from file: 1135
# 131: Loading 57 QSO spec. from file: 1136
# 132: Loading 51 QSO spec. from file: 1137
# 133: Loading 56 QSO spec. from file: 1138
# 134: Loading 52 QSO spec. from file: 1139
# 135: Loading 51 QSO spec. from file: 1140
# 136: Loading 40 QSO spec. from file: 1141
# 137: Loading 60 QSO spec. from file: 1142
# 138: Loading 71 QSO spec. from file: 1143
# 139: Loading 47 QSO spec. from file: 1144
# 140: Loading 39 QSO spec. from file: 1145
# 141: Loading 36 QSO spec. from file: 1146
# 142: Loading 56 QSO spec. from file: 1147
# 143: Loading 53 QSO spec. from file: 1148
# 144: Loading 51 QSO spec. from file: 1149
# 145: Loading 42 QSO spec. from file: 1150
# 146: Loading 49 QSO spec. from file: 1151
# 147: Loading 20 QSO spec. from file: 1153
# 148: Loading 16 QSO spec. from file: 1154
# 149: Loading 44 QSO spec. from file: 1155
# 150: Loading 52 QSO spec. from file: 1156
# 151: Loading 50 QSO spec. from file: 1157
# 152: Loading 46 QSO spec. from file: 1158
# 153: Loading 62 QSO spec. from file: 1159
# 154: Loading 57 QSO spec. from file: 1160
# 155: Loading 64 QSO spec. from file: 1161
# 156: Loading 57 QSO spec. from file: 1162
# 157: Loading 46 QSO spec. from file: 1163
# 158: Loading 46 QSO spec. from file: 1164
# 159: Loading 44 QSO spec. from file: 1165
# 160: Loading 52 QSO spec. from file: 1166
# 161: Loading 59 QSO spec. from file: 1167
# 162: Loading 54 QSO spec. from file: 1168
# 163: Loading 65 QSO spec. from file: 1169
# Reading done.

# %%
if 0:   #  Save / Load continuum with 10k obj catalog.
   np.save('wave',mwave11)
   np.save('meanf',mmean11)
   np.save('meanstd',mstd11)
else:
   mwave11 = np.load('wave.npy')
   mmean11 = np.load('meanf.npy')
   mstd11 = np.load('meanstd.npy')

plt.plot(mwave11, mmean11)
plt.xlabel(r'wavelenght$_{rest}$ (A)')
plt.ylabel(r'Intensity / $I_0$')
plt.xlim(1050,1600)

#plt.plot(mwave11, mstd11)
# Out:
# (1050, 1600)

# %%
#### One QSO ploting example


spectra = spectra_Desi
QSOloc = QSOloc_Desi
wwave = np.arange( lmin, lmax, .1) 


specSize = len(spectra)
specSize = 10

pcafluxm  = np.zeros(( specSize, wwave.size))
pcaivarm  = np.zeros(( specSize, wwave.size))

for nspectra in range( 0, specSize):
   # nspectra = 100
   s = spectra[ nspectra ]
   z, dec, ra, id_ = QSOloc[ nspectra ]
   w_ = s[0]
   wmask = (w_>1040) & ( w_<1160)
   
   w_ = w_[wmask]
   if len(w_) > 0:
      flux_ = s[1]
      ivar_ = s[2]

      flux_ = flux_[wmask]
      ivar_ = ivar_[wmask]


      param = scpo.minimize(chi2, (1,1), args=( w_, flux_, ivar_) ); #COBYLA
      delta_ = flux_ / (param.x[0]*w_+param.x[1])  -  1



      pcafluxm[nspectra], pcaivarm[nspectra] = resample_flux( wwave, w_, flux_, ivar_ ) # interpolation

      plt.plot(w_,flux_)
      plt.plot(wwave, pcafluxm[nspectra], 'c.-',label = 'London data' )

      plt.plot(w_, param.x[0]*w_+param.x[1],'b', label = 'Weighted linreg'  )
      plt.plot(mwave11, mmean11, label='PCA continuum')
      plt.xlim(np.min(w_),np.max(w_))
      plt.legend()

   #else:
   #   np.delete( spectra[nspectra] )

      plt.xlabel( r'$Wavelenght\, [\AA]$, QSO: Z=' + str( z) + ',\n DEC=' + str( dec) +', RA=' + str( ra)  )
      plt.ylabel( r'$\delta$ (not centered)' )
      plt.show()

# %%
# def comovil distance calculation

z_ = np.linspace(0, 5., 1000)
r_ = np.zeros(1000)

omega_m = 0.31
omega_L = 0.69
cH0 = 3000

Hz = np.sqrt( omega_m * (1+z_)**3 + omega_L )

# defining the integral
dz = z_[1]-z_[0]

for i in range(1, z_.size):
    r_[i] = np.sum( cH0/Hz[:i] )*dz

def Rcomv(wave):
   z = (wave)/1216 - 1
   return np.interp(z, z_, r_)

# def conversion of r, declination and ra to x y z
def coordC(r,ra,dec):
   return r*np.cos(dec)*np.cos(ra), r*np.cos(dec)*np.sin(ra), r*np.sin(dec)

# %%
# OUTPUT function

#  z     = QSOloc_Desi[ i ][0]
#  dec   = QSOloc_Desi[ i ][1]
#  ra    = QSOloc_Desi[ i ][2]
#  id    = QSOloc_Desi[ i ][3]
#  w_    = spectra_Desi[ i ][ 0 ]
#  flux_ = spectra_Desi[ i ][ 1 ]
#  ivar_ = spectra_Desi[ i ][ 2 ]


def writeDelta(path_out, QSOloc, spectra, cat_type, nside_=8, nest_=False):
# save output
   
   A = np.array( QSOloc )
   
   pix = healpy.ang2pix( nside_ , sp.pi/2.-A[:,1], A[:,2], nest=nest_ )
   tags = np.unique(pix)

   print('Writting data from '+ str(len(QSOloc))+' QSOs')
   
   if ( cat_type == 'eBoss'):
      for i in range(0, len(QSOloc) ):
         hd = [ {'name':'RA','value':QSOloc[ i ][2],'comment':'Right Ascension [rad]'},
                 {'name':'DEC','value':QSOloc[ i ][1],'comment':'Declination [rad]'},
                 {'name':'Z','value':QSOloc[ i ][0],'comment':'Redshift'},
                 #{'name':'PMF','value':'{}-{}-{}'.format(d.plate,d.mjd,d.fid)},
                 {'name':'FIBER_ID','value':QSOloc[ i ][3],'comment':'Object identification'},
                 #{'name':'PLATE','value':d.plate},
                 #{'name':'MJD','value':d.mjd,'comment':'Modified Julian date'},
                 #{'name':'FIBERID','value':d.fid},
                 {'name':'ORDER','value':1,'comment':'Order of the continuum fit'},
         ]
         cols=[np.log10( spectra[i][0] ), spectra[i][1]*0, spectra[i][2], spectra[i][1]]
         names=['LOGLAM','DELTA','WEIGHT','CONT']
         units=['Log Angstrom','','','']
         comments = ['Log Lambda','Delta field','Pixel weights','Continuum']
         
         out.write(cols,names=names,header=hd,comment=comments,units=units,extname=str(QSOloc[ i ][3]))
   
   elif ( cat_type == 'Desi'):
      for j in range(0, len(tags)):
         out = fitsio.FITS(path_out+'/delta-'+ str(tags[j]) +'.fits.gz','rw',clobber=True)
         mask = pix == int( tags[j])
         ar  =  np.squeeze( np.where(mask) )
         
         #print( tags[j], len(ar) )
         for i in ar:
            hd = [ {'name':'RA','value':QSOloc[ i ][2],'comment':'Right Ascension [rad]'},
                    {'name':'DEC','value':QSOloc[ i ][1],'comment':'Declination [rad]'},
                    {'name':'Z','value':QSOloc[ i ][0],'comment':'Redshift'},
                    #{'name':'PMF','value':'{}-{}-{}'.format(d.plate,d.mjd,d.fid)},
                    {'name':'TARGET_ID','value':QSOloc[ i ][3],'comment':'Object identification'},
                    #{'name':'PLATE','value':d.plate},
                    #{'name':'MJD','value':d.mjd,'comment':'Modified Julian date'},
                    #{'name':'FIBERID','value':d.fid},
                    {'name':'ORDER','value':1,'comment':'Order of the continuum fit'},
            ]
            cols=[np.log10( spectra[i][0] ), spectra[i][1], spectra[i][2], spectra[i][1]]
            names=['LOGLAM','DELTA','WEIGHT','CONT']
            units=['Log Angstrom','','','']
            comments = ['Log Lambda','Delta field','Pixel weights','Continuum']

            out.write(cols,names=names,header=hd,comment=comments,units=units,extname=str(QSOloc[ i ][3]))
            
         out.close()
         print('Done writting to file '+str(tags[j])+'.' )
      print('Writing done')

path_out = '/work/sfbeltranv/lyad_output'

#writeDelta(path_out, QSOloc_eBoss, spectra_eBoss, 'eBoss')
writeDelta(path_out, QSOloc_Desi, spectra_Desi, 'Desi')
# Out:
# Writting data from 7624 QSOs
# Done writting to file 21.
# Done writting to file 36.
# Done writting to file 145.
# Done writting to file 146.
# Done writting to file 147.
# Done writting to file 177.
# Done writting to file 178.
# Done writting to file 179.
# Done writting to file 210.
# Done writting to file 211.
# Done writting to file 212.
# Done writting to file 242.
# Done writting to file 243.
# Done writting to file 274.
# Done writting to file 275.
# Done writting to file 276.
# Done writting to file 305.
# Done writting to file 306.
# Done writting to file 307.
# Done writting to file 337.
# Done writting to file 338.
# Done writting to file 339.
# Done writting to file 340.
# Done writting to file 368.
# Done writting to file 369.
# Done writting to file 370.
# Done writting to file 371.
# Done writting to file 400.
# Done writting to file 401.
# Done writting to file 402.
# Done writting to file 403.
# Done writting to file 430.
# Done writting to file 431.
# Done writting to file 432.
# Done writting to file 433.
# Done writting to file 434.
# Done writting to file 461.
# Done writting to file 462.
# Done writting to file 463.
# Done writting to file 464.
# Done writting to file 465.
# Done writting to file 466.
# Done writting to file 494.
# Done writting to file 495.
# Done writting to file 497.

# %%
# Speed test for delta function selection
def f(a,b):
    return a+b
import timeit

deltaF = 'f'


start = timeit.default_timer()
#Your statements here
f(3, 4)
stop = timeit.default_timer()
print('Time: ', stop - start)  

n=3241241
start = timeit.default_timer()
#Your statements here
if n >= 0:
   f(3, 4)
elif(n>45):
   f(4,5)
else:
   f(1,1)
stop = timeit.default_timer()
print('Time: ', stop - start)  

start = timeit.default_timer()
#Your statements here
eval(deltaF)(3, 4)
stop = timeit.default_timer()
print('Time: ', stop - start)

# %%
def get_pca( spectra, niter, nvec, lmin = 1040, lmax = 1600 ):

   #### One QSO ploting example

   wwave = sp.arange( lmin, lmax, .1) 

   nbObj = len(spectra)
   # nbObj = 20

   pcaflux  = sp.zeros(( nbObj, wwave.size))
   pcaivar  = sp.zeros(( nbObj, wwave.size))

   for nspectra in range( 0, nbObj):
      pcaflux[nspectra], pcaivar[nspectra] = resample_flux( wwave, spectra[ nspectra ][0], spectra[ nspectra ][1], spectra[ nspectra ][2]) # interpolation

   pcaivar[pcaivar<0.] = 0.   # Remove if all measured bins are zero
   w = sp.sum(pcaivar,axis=0)>0.
   pcawave = wwave[w]
   pcaflux = pcaflux[:,w]
   pcaivar = pcaivar[:,w]
   ### Cap the ivar
   pcaivar[pcaivar>100.] = 100.

   ### Get the mean
   data_meanspec = sp.average(pcaflux,weights=pcaivar,axis=0) # Here, I get the mean spectrum.
   for i in range(nbObj):       #
      w = pcaivar[i]>0.        # subtracting the mean for each spectrum
      pcaflux[i,w] -= data_meanspec[w] #

   ### PCA
   print('INFO: Starting EMPCA')
   dmodel = empca.empca(pcaflux, weights=pcaivar, niter=niter, nvec=nvec)
        
   return dmodel, pcawave, pcaflux, pcaivar, data_meanspec

# %%
def get_continuum(wavelength,coeff,eigvec,mean_spec,n_vec=4,lmin=1300.0,lmax=1500.0,dw = 0.28):
   ### Choose the first four eigenvectors
   conti_mock = []
   for i in range(len(coeff)):
      spectram = []
      for j in range(n_vec):
         spectram.append(coeff[i][j]*eigvec[j])
      spectrasm = np.vstack(spectram)
      specm = np.sum(spectrasm,axis = 0)
      conti_mock += [specm]
   continuum_mock = np.vstack(conti_mock)
   ###
   new_wave = np.arange(600, 3000, dw)
   flux_mock = np.zeros((len(continuum_mock), new_wave.size))
   for i in range(len(continuum_mock)):
      flux_mock[i] = resample_flux(new_wave, wavelength, mean_spec+continuum_mock[i])
   ### Normalization
   integral_mock = []
   continuum_nor_mock = []
   for i in range(len(flux_mock)):
      sum2=0
      for j in range(len(flux_mock[i])):
         if lmin <= new_wave[j] < lmax :
            sum2+=(flux_mock[i][j])*(new_wave[j+1]-new_wave[j])
         elif (new_wave[j] > lmax):
            break
      integral_mock.append(sum2)
      continuum_nor_mock.append(8*flux_mock[i]/sum2)
   contin_mock = np.vstack(continuum_nor_mock)
   ### Normalization for the eigenvalues.
   coefficient = np.zeros((4,len(coeff)))
   for k in range(4):
      coefficient[k] = coeff[:,k]/integral_mock
   ### Stack
   stack_mock = np.mean(contin_mock,axis=0)     # mean continuum.
   std_stack_mock = np.std(contin_mock,axis=0)  # standard deviation.
   return new_wave, stack_mock, std_stack_mock, coefficient, contin_mock


#dmodel, pcawave, pcaflux, pcaivar, data_meanspec = get_pca(spectra_eBoss, 10, 10)
#dwave11, dmean11, dstd11, dcoeff11, dcontin_mock = get_continuum( pcawave, dmodel.coeff, dmodel.eigvec, data_meanspec)

dmodel, pcawave, pcaflux, pcaivar, data_meanspec = get_pca(spectra_Desi, 10, 10)
mwave11, mmean11, mstd11, mcoeff11, mcontin_mock = get_continuum( pcawave, dmodel.coeff, dmodel.eigvec, data_meanspec)
# Out:
# /home/sfbeltranv/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: scipy.arange is deprecated and will be removed in SciPy 2.0.0, use numpy.arange instead
#   """
# /home/sfbeltranv/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: DeprecationWarning: scipy.zeros is deprecated and will be removed in SciPy 2.0.0, use numpy.zeros instead
#   # Remove the CWD from sys.path while we load stuff.
# /home/sfbeltranv/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DeprecationWarning: scipy.zeros is deprecated and will be removed in SciPy 2.0.0, use numpy.zeros instead
#   # This is added back by InteractiveShellApp.init_path()
# /home/sfbeltranv/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: DeprecationWarning: scipy.sum is deprecated and will be removed in SciPy 2.0.0, use numpy.sum instead
# /home/sfbeltranv/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:25: DeprecationWarning: scipy.average is deprecated and will be removed in SciPy 2.0.0, use numpy.average instead
# INFO: Starting EMPCA
# /home/sfbeltranv/.bins/empca.py:256: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   x = np.linalg.lstsq(A, b)[0]
#        iter        R2             rchi2
# EMPCA  1/10       0.00331912      0.00063050
# EMPCA  2/10       0.02192651      0.00062109
# EMPCA  3/10       0.04296303      0.00060846
# EMPCA  4/10       0.05712690      0.00060146
# EMPCA  5/10       0.06133025      0.00059948
# EMPCA  6/10       0.06303309      0.00059872
# EMPCA  7/10       0.06390749      0.00059836
# EMPCA  8/10       0.06442837      0.00059816
# EMPCA  9/10       0.06477034      0.00059802
# EMPCA 10/10       0.06503031      0.00059792
# R2: 0.06536082676779398

# %%
def plot_mean_cont(mwave,mflux,dwave,dflux,stdm,stdd,zmin,zmax,magmin,magmax,xmin,xmax,xminzoom,xmaxzoom):
   plt.figure(figsize=(14,15))
   plt.subplot(2,1,1)
   plt.title('Mean Continuum     {} < MAG < {} and {} < z < {}.'.format(magmin,magmax,zmin,zmax),fontsize = 20)
   plt.plot(dwave,dflux,'-', label='Stack DR14',alpha=0.7)
   #plt.fill_between(new_wave,stack_boss+std_stack_boss,stack_boss-std_stack_boss, label='std BOSS', color = 'y', alpha=0.5)
   plt.plot(mwave,mflux,'-', label='Stack MOCK',alpha=0.7)
   #plt.fill_between(new_wave,stack_mock+std_stack_mock,stack_mock-std_stack_mock, label='std MOCK', color = 'k', alpha=0.4)
   plt.xlim(xmin,xmax)
   #plt.ylim(-0.002,0.01)
   #axvline(940.93)
   plt.xlabel('$\lambda_{R.F.}$', fontsize = 20)
   plt.ylabel('$\mathrm{\overline{Normalized \enspace Flux}}$', fontsize = 20)
   plt.legend(fontsize='xx-large')
   plt.grid()

   mask = (dwave>900) & (dwave<1216)

   plt.subplot(2,1,2)
   plt.plot(dwave[mask],dflux[mask], label='Stack DR14')
   plt.fill_between(dwave[mask],dflux[mask]+stdd[mask],dflux[mask]-stdd[mask], label='std BOSS', color = 'y', alpha=0.5)
   plt.plot(mwave[mask],mflux[mask], label='Stack MOCK')
   plt.fill_between(mwave[mask],mflux[mask]+stdm[mask],mflux[mask]-stdm[mask], label='std MOCK', color = 'k', alpha=0.4)
   plt.xlim(xminzoom,xmaxzoom)
   #plt.ylim(0,0.04)
   plt.xlabel('$\lambda_{R.F.}$', fontsize = 20)
   plt.ylabel('$\mathrm{\overline{Normalized \enspace Flux}}$', fontsize = 20)
   plt.legend(fontsize='xx-large')
   plt.grid()

#plot_mean_cont(mwave11,mmean11,mwave11,mmean11,mstd11,mstd11,2.4,2.6,20.0,20.5,990,2200,990,1216)

# %%
#nqso = 10


#plt.plot( pcawave, pcaflux[nqso] )
#plt.figure()
#plt.plot( dwave11, dcontin_mock[nqso] )
#plt.xlim((1040, 1500))  
#plt.figure()
#plt.plot( dwave11, dmean11 )

# %%
### PICCA loading example
if 0:
   dir  = '/work/sfbeltranv/output/deltas'


   catalog = pyfits.open(dir + 'delta-103.fits.gz')

   catalog[1].header

   #plt.plot( (10**catalog[1].data['LOGLAM'])/(1+catalog[1].header['Z']), catalog[1].data['DELTA'] )
   wlen = (10**catalog[1].data['LOGLAM'])/(1+catalog[1].header['Z'])

   print( wlen[0] )
   print(wlen[-1])



   catalog[1].header['THING_ID']
   catalog[1].header['Z']
   catalog[1].header

# %%
## PCA Calculation Example

# OUTPUT function
#  z     = QSOloc[ i ][0]
#  dec   = QSOloc[ i ][1]
#  ra    = QSOloc[ i ][2]
#  id    = QSOloc[ i ][3]
#  w_    = spectra[ i ][ 0 ]
#  flux_ = spectra[ i ][ 1 ]
#  ivar_ = spectra[ i ][ 2 ]

spectra = spectra_eBoss
QSOloc = QSOloc_eBoss

dmodel, pcawave, pcaflux, pcaivar, data_meanspec = get_pca(spectra, 10, 10)
mwave11, mmean11, mstd11, mcoeff11, mcontin_mock = get_continuum( pcawave, dmodel.coeff, dmodel.eigvec, data_meanspec)

# %%
### PCA delta calculation and centering
def getdeltas_PCA( spectra, QSOloc, pcawave, pcacont, pcaivar, lamin=1040, lamax=1200):

   deltas = []

   for i in range( len(QSOloc) ):         # len(QSOloc)
      dwave = spectra[ i ][ 0 ]
      wmask = ( dwave >= lamin ) & ( dwave <= lamax )
      dwave = dwave[ wmask ]
      flux  = spectra[ i ][ 1 ]
      flux  = flux[ wmask]                        # orig flux
      ivr  =  spectra[ i ][ 2 ]
      ivr = ivr[ wmask]
      
      # pcawave, pcacont from cont. fitting with PCA to QSO delta ticks 
      # pcacont from pcawave to dwave
      cont, contivar  = resample_flux(dwave, pcawave, pcacont, ivar=pcaivar  )   # continuum to dwave grid
      
      delta = flux / cont - 1
      delta = delta - np.sum(delta) / len(delta)     # zero Centered delta

      dwave = dwave * ( 1 + QSOloc[ i ][0] )   # restframe to selframe
      
      s=np.vstack( ( dwave.conj().transpose(), delta.conj().transpose(), ivr.conj().transpose(), cont.conj().transpose()  ) )
      deltas.append( s )
      #plt.figure()
      #plt.plot(dwave, flux, 'b') # orig flux
      #plt.plot(dwave, fluxm, 'r') # zero centered flux
      #plt.plot(dwave, flux*0+np.sum(flux) / len(flux) )  # mean of orig flux
      #plt.plot(dwave, fluxm*0, 'y')                      # zero line
      #plt.plot(dwave, delta)                              # continuum
      #plt.plot(dwave, cont)
      #plt.show()
   
   return deltas


deltas_Desi_PCA = getdeltas_PCA(spectra_Desi, QSOloc_Desi, mwave11, mmean11, mstd11 )
print('done')
print(len(deltas_Desi_PCA))
# Out:
# done
# 10

# %%
def getdeltas_LinMinimize( spectra, QSOloc, lamin=1040, lamax=1200):

   deltas = []

   for i in range( len(QSOloc) ):         # len(QSOloc)
      
      w_, flux_, ivar_ = spectra[ i ]
      z, dec, ra, id_ = QSOloc[ i ]
      
      wmask = ( w_ >= lamin ) & ( w_ <= lamax )
      w_ = w_[wmask]
      flux_ = flux_[wmask]
      ivar_ = ivar_[wmask]
      
      param = scpo.minimize(chi2, (1,1), args=( w_, flux_, ivar_) ); #COBYLA
      CF = (param.x[0]*w_+param.x[1])
      
      delta_ = flux_ / CF  -  1
      delta_ = delta_ - np.sum(delta_) / len(delta_)     # zero Centered delta

      # dwave to observer frame and to comoving distance
      w_ = w_ * ( 1 + QSOloc[ i ][0] )   # restframe to selframe

      s=np.vstack( ( w_.conj().transpose(), delta_.conj().transpose(), ivar_.conj().transpose(), CF.conj().transpose() ) )
      deltas.append( s )
      
      #plt.figure()
      #plt.plot( w_,flux_ )
      #plt.plot( w_, delta_ )
      #plt.plot( w_, CF, 'r' )
      #plt.show()
   
   return deltas


deltas_Desi_linMin = getdeltas_LinMinimize(spectra_Desi, QSOloc_Desi )
print('done')
print(len(deltas_Desi_linMin))
# Out:
# done
# 7624

# %%
def load_Picca():

   ################# delta reading and loading with thing_id
   dir  = '/work/sfbeltranv/output/deltas'

   '''
   catalog = pyfits.open(dir + 'delta-100.fits.gz')

   catalog[1].header

   plt.plot( catalog[1].data['LOGLAM'], catalog[1].data['DELTA'] )

   catalog[1].header
   catalog[1].header['THING_ID']
   '''

   ################## script to load al healpix piles


   fi = glob.glob(dir+'/*')
   print( len(fi) )
   spectra = []
   QSOloc = []

   for i in range( 0, len(fi) ):   # len( fi )
      catalog = pyfits.open( fi[i] ) 
      for j in range(1, len(catalog) ):
         QSOloc.append( np.hstack(( catalog[j].header['Z'], catalog[j].header['DEC'], catalog[j].header['RA'], int(catalog[j].header['THING_ID']) )) ) 
         # print(int(catalog[j].header['THING_ID']))
         s=np.vstack( ( 10**catalog[j].data['LOGLAM'], catalog[j].data['DELTA'], catalog[j].data['WEIGHT'] ) )
         spectra.append( s )
         
   return QSOloc, spectra


QSOloc_Picca, deltas_Picca = load_Picca()
print( len(deltas_Picca) )
# Out:
# 45
# 6408

# %%
def getHist_deltas(deltas):

   min = 10000
   max = 0
   for i in range( len(deltas) ): 
      lmin = np.amin( deltas[i][0])
      lmax = np.amax( deltas[i][0])
      if( lmin  < min ):
         min = lmin
      if( lmax  > max ):
         max = lmax
   print( min, max )

   bin, step = np.linspace( np.ceil(min), np.ceil(max),  num =  int(1*(1+  np.ceil(max)-np.ceil(min) ) ), retstep=True  )
   print(step)
   print(len(bin))
   print( bin[0] )
   print( bin[-1] )

   catalogLen = len(deltas)

   histZ = np.zeros_like((bin))
   len(histZ)

   for i in range( catalogLen ): 
      wave = deltas[i][0]
      delta = deltas[i][1]
      for j in range( len(wave) ): 
         ind = int( np.floor( (wave[j] -bin[0]+step) / step ) )
         histZ[ind] = histZ[ind] + delta[j]

   plt.plot(Rcomv( bin ),histZ)
   plt.xlim(3500,5000)
   #plt.ylim(-100,1000)
   plt.xlabel('$\lambda (Angstrom)$')
   plt.ylabel('$\sum_i^{ N_{QSO} }\delta_i (\lambda)$')

   plt.show()
   

getHist_deltas(deltas_Picca)
plt.ylim(-300,600)
getHist_deltas(deltas_Desi_linMin)
#plt.ylim(-10,100)
getHist_deltas(deltas_Desi_PCA)

# %%
def compareDelta1(QSOloca, QSOlocb, spectraa1, spectraa2, spectrab):
# b for picca, a for Desi or eBoss
   a = np.array( QSOloca )
   b = np.array( QSOlocb )
   
   for i in  [4, 5, 6, 7] :         # range( len(b) ):
      indx = np.where( a[:,3] == b[i][3] )
      indx = np.squeeze(indx)
      ###  a -- indx, b --- i
      wa1_, fluxa1_, ivara1_ = spectraa1[ indx ]
      wa2_, fluxa2_, ivara2_ = spectraa2[ indx ]
      wb_, fluxb_, ivarb_ = spectrab[ i ]
      
      if 1:         # Resample flux to picca wave
      # fluxa from wa to wb
         fluxa1_  = resample_flux( wb_, wa1_, fluxa1_ )   # continuum fo dwave grid
         fluxa2_  = resample_flux( wb_, wa2_, fluxa2_ )   # continuum fo dwave grid
         wa1_ = wb_
         wa2_ = wb_
      print(wa1_[0], wa1_[-1])
      print(wb_[0], wb_[-1])

      
      plt.figure()
      plt.plot( Rcomv(wa2_), fluxa2_, 'black', label='LinReg' )
      plt.plot( Rcomv(wa1_), fluxa1_, 'b', label='PCA' )
      plt.plot( Rcomv(wb_), fluxb_, 'r', label='PICCA' )
      plt.legend( loc='upper right' )
      plt.xlabel('$\lambda (Angstrom)$')
      plt.ylabel('$\delta (\lambda)$')
      print( r"$\delta_{PICCA}$", wb_[0]-wb_[1], r"   $\delta_{Instrument}$", wa1_[0]-wa1_[1] )
      
      #print(a[indx,3])
      #print(b[i,3])
   plt.show()


compareDelta1( QSOloc_Desi, QSOloc_Picca, deltas_Desi_PCA, deltas_Desi_linMin, deltas_Picca )

# %%
l = np.linspace(1040., 1200., 1000)
alpha = .8
l2 = alpha*l-alpha*1080+1040
l3 = alpha*l

plt.plot(l,l3)
plt.plot(l,l2)
plt.plot(1160,1200., 'ro')
plt.plot(1080,1040., 'ro')
plt.plot(l,l*0+1040)
plt.plot(l,l*0+1200)
plt.grid()

# %%
# QSOloc_eBoss, spectra_eBoss
# Healpix example

# OUTPUT function
#  z     = QSOloc[ i ][0]
#  dec   = QSOloc[ i ][1]
#  ra    = QSOloc[ i ][2]
#  id    = QSOloc[ i ][3]
#  w_    = spectra[ i ][ 0 ]
#  flux_ = spectra[ i ][ 1 ]
#  ivar_ = spectra[ i ][ 2 ]

a =  np.squeeze( np.array(QSOloc_Desi ) )
a = np.array(QSOloc_Desi)
#print( a[:][1] )
print( a.shape )

#print(a[0:4, 3])
#print(a[0:4, 2])
print('array: ', a[:,1])
#print('full: ', QSOloc_Desi)

#print( np.hstack( ( a[:,1],a[:,2] ) ) )

#print(  np.unique(a[:,4] ) )

nside = 8
nest = True


heal_pix = healpy.ang2pix(nside, sp.pi/2.-a[:,1], a[:,2], False)
print( np.unique(heal_pix) )

# %%
save = '/work/sfbeltranv/lyad_output/delta-145.fits.gz'
savep = '/work/sfbeltranv/output/deltas/delta-145.fits.gz'

a = Table.read(save)
print( a )
ap = Table.read(savep)
print( ap.colnames )
# Out:
#       LOGLAM       DELTA       WEIGHT               CONT
#    Log Angstrom
# ------------------ ----- ------------------ --------------------
# 3.0171072890157005   0.0  1.237464427947998  0.08868128486046072
# 3.0172179119289315   0.0 1.2664045095443726   0.0883202988938986
# 3.0173285066716167   0.0 1.3049883842468262  0.04968377527050792
# 3.0174390732580996   0.0 1.3310563564300537 0.039081414088400074
# 3.0175496117027136   0.0  1.334619164466858  0.09514101604909905
#   3.01766012201978   0.0 1.4087363481521606 0.003167888385401393
# 3.0177706042236094   0.0 1.4660289287567139 0.011787730295722375
#  3.017881058328503   0.0 1.3619184494018555  0.01293758746492591
# 3.0179914843487494  -0.0 1.3190844058990479 -0.09092097369903057
# 3.0181018822986267   0.0 1.4567811489105225  0.08073641902452963
#                ...   ...                ...                  ...
#  3.203425435814076   0.0  7.599884033203125  0.03712297870557554
# 3.2034974712583417   0.0  8.873815536499023  0.04422743749423412
# 3.2035694947562328   0.0  9.985987663269043  0.03920850420002346
# 3.2036415063117105   0.0   10.6284818649292 0.034317043539009856
# 3.2037135059287345   0.0 10.782499313354492 0.031230344687311833
# 3.2037854936112633   0.0 10.780126571655273 0.028148577503939676
# 3.2038574693632524   0.0  10.23040771484375  0.04465955102368959
#  3.203929433188655   0.0  9.071517944335938  0.06408978083246072
# 3.2040013850914244   0.0  9.423723220825195  0.01722836591889413
# 3.2040733250755093   0.0  10.28111457824707  0.04694528544981809
# Length = 2113 rows
# ['LOGLAM', 'DELTA', 'WEIGHT', 'CONT']
