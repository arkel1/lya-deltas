# %%
import numpy as np
import scipy as sp
from astropy.io import fits as pyfits
from astropy.table import Table
import desispec.io
#from desispec.interpolation import resample_flux
#from desitarget.targetmask import desi_mask
#import sys
import os
import scipy.optimize as scpo
import matplotlib.pyplot as plt

import fitsio

# Desi catalog test
import glob
from itertools import compress
import healpy

# %%
####  Catalog cutter eBoss

file = '/work3/desi_lya/data/eBOSS/dr15_all/DR14Q_v4_4.fits' # Add here the filename, include the full path if necesary
output = '/work/sfbeltranv/DR14_mini/DR14Q_v4_4m.fits'
hdul = pyfits.open(file)
data = hdul[1].data
hdul.info()

# Nor: Origina size, Nnew: new size for the catalog (in overall items)
Nor = len(data)
Nnew = 600

# Random Mask of Nnew items from the Nor items of the orignal catalog
w = np.random.choice(Nor,Nnew,replace=False)

if os.path.exists(output):
  os.remove(output)

# Mask set in the catalog
hdul[1].data = data[w]
hdul.writeto(output)   # change name to the desired one.
hdul.close()
print('\n\nDone writing.\n')


hdul = pyfits.open( output )
data = hdul[1].data
hdul.info()
hdul.close() 
print('\nDone with final size= ', len(data) )
# Out:
# Filename: /work3/desi_lya/data/eBOSS/dr15_all/DR14Q_v4_4.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      16   (7055,)   uint8
#   1  DR14Q_v4_4    1 BinTableHDU    328   526356R x 105C   ['18A', 'D', 'D', 'J', 'I', 'J', 'I', '4A', 'D', 'D', '4A', 'D', 'D', 'D', 'I', 'D', 'D', 'D', 'K', 'K', 'K', 'K', 'K', 'K', 'I', 'I', 'I', '51J', '51J', '51J', '51A', 'D', 'D', 'I', 'A', 'I', 'I', 'A', '5D', '5D', '5D', '5D', 'D', '5D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'E', 'D', 'D', 'D', 'D', 'D', 'D', 'E', 'I', 'D', 'D', 'E', 'I', 'D', 'D', 'E', 'I', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', '4A', '4A', 'D', 'E', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'I', 'D', 'D', 'D']
#
#
# Done writing.
#
# Filename: /work/sfbeltranv/DR14_mini/DR14Q_v4_4m.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      16   (7055,)   uint8
#   1  DR14Q_v4_4    1 BinTableHDU    328   600R x 105C   ['18A', 'D', 'D', 'J', 'I', 'J', 'I', '4A', 'D', 'D', '4A', 'D', 'D', 'D', 'I', 'D', 'D', 'D', 'K', 'K', 'K', 'K', 'K', 'K', 'I', 'I', 'I', '51J', '51J', '51J', '51A', 'D', 'D', 'I', 'A', 'I', 'I', 'A', '5D', '5D', '5D', '5D', 'D', '5D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'E', 'D', 'D', 'D', 'D', 'D', 'D', 'E', 'I', 'D', 'D', 'E', 'I', 'D', 'D', 'E', 'I', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', '4A', '4A', 'D', 'E', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'I', 'D', 'D', 'D']
#
# Done with final size=  600

# %%
####  Catalog cutter Desi

file = '/work3/desi_lya/mocks_quick/london/v9.0.0_small/zcat.fits' # Add here the filename, include the full path if necesary
output = '/work/sfbeltranv/DR14_mini/zcat_m.fits'
hdul = pyfits.open(file)
data = hdul[1].data
hdul.info()

# Nor: Origina size, Nnew: new size for the catalog (in overall items)
Nor = len(data)
Nnew = 600

# Random Mask of Nnew items from the Nor items of the orignal catalog
w = np.random.choice(Nor,Nnew,replace=False)

if os.path.exists(output):
  os.remove(output)

# Mask set in the catalog
hdul[1].data = data[w]
hdul.writeto(output)   # change name to the desired one.
hdul.close()
print('\n\nDone writing.\n')


hdul = pyfits.open( output )
data = hdul[1].data
hdul.info()
hdul.close() 
print('\nDone with final size= ', len(data) )
# Out:
# Filename: /work3/desi_lya/mocks_quick/london/v9.0.0_small/zcat.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       6   ()
#   1  ZCATALOG      1 BinTableHDU     39   142128R x 15C   ['D', '4D', 'D', 'D', 'K', '96A', '16A', 'K', 'D', '8A', 'D', 'D', 'E', 'E', 'E']
#
#
# Done writing.
#
# Filename: /work/sfbeltranv/DR14_mini/zcat_m.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       6   ()
#   1  ZCATALOG      1 BinTableHDU     39   600R x 15C   ['D', '4D', 'D', 'D', 'K', '96A', '16A', 'K', 'D', '8A', 'D', 'D', 'E', 'E', 'E']
#
# Done with final size=  600

# %%
#### Catalog loading and mask example:

catalog=Table.read('/work/sfbeltranv/DR14_mini/DR14Q_v4_4m.fits')
w=(catalog['THING_ID']>0) & (catalog['Z']>2) & (catalog['Z']<4) & (catalog['RA']!=catalog['DEC'])& (catalog['RA']>0) & (catalog['DEC']>0)
reduced_cat=catalog[w]

# Final reduced_cat size:
print(( np.sum(w) ))
print( len(reduced_cat) )
# Out:
# 234
# 234
# WARNING: UnitsWarning: 'erg/s/cm2' contains multiple slashes, which is discouraged by the FITS standard [astropy.units.format.generic]
# WARNING: UnitsWarning: 'W/m2/Hz' contains multiple slashes, which is discouraged by the FITS standard [astropy.units.format.generic]

# %%
#####################################
# Load QSO from plates     eBoss
### Parameters
path_spec      = '/work3/desi_lya/data/eBOSS/dr15_all/spplates'
path_drq       = '/work/sfbeltranv/DR14_mini/DR14Q_v4_4m.fits'

# for line correction (later)
#path_lines     = '/work3/desi_lya/data/eBOSS/dr12_all/dr16-line-sky-mask.txt'

zmin = 2
zmax = 4

# %%
def load_eBoss(path_drq, path_spec, zmin, zmax):
   # eBoss Catalog load
   catalog = Table.read(path_drq)
   
   lya = 1200 # 1215.67 1200
   w = (catalog['THING_ID']>0) & (catalog['Z'] > zmin ) & (catalog['Z']< zmax ) & (catalog['RA']!=catalog['DEC'])& (catalog['RA']>0) & (catalog['DEC']>0)
   reduced_cat = catalog[w]
   reduced_cat = reduced_cat.group_by('PLATE')

   # thing_id = reduced_cat['THING_ID']
   fiberid = reduced_cat['FIBERID']
   plate = reduced_cat['PLATE']
   zqso = reduced_cat['Z']
   DEC = reduced_cat['DEC']
   RA = reduced_cat['RA']

   plate_list=[]
   for p,m in zip(reduced_cat['PLATE'],reduced_cat['MJD']):
        plate_list.append(str(p)+'/spPlate-'+str(p)+'-'+str(m)+'.fits')
   plate_list=np.unique(plate_list)

    #thisplate=plate_list[0].split("/")[1]  # Location
    #thisplate=plate_list[0].split("/")[0]  # Plate Number
   print('Found '+ str(  np.sum(w) ) + ' QSO spec. in catalog: '+ path_drq )
    
   spectra = []
   QSOloc = []
   ## begin for test
   for nplate in range ( 0, len(plate_list) ):
      plate1=pyfits.open( path_spec+'/'+plate_list[nplate].split("/")[1] )
      thisplate=plate_list[nplate].split("/")[0]  # Plate Number

      wp = plate == int( thisplate )
      ids_=fiberid[wp]
      zqso_=zqso[wp]
      DEC_ = DEC[wp]
      RA_ = RA[wp]
      
      nqsoPlate_= ids_.shape[0]
      print( str(nplate) + ': Loading '+ str(nqsoPlate_) +' QSO spec. from plate: '+ plate_list[nplate].split("/")[1] )
      # Reading data from plate
      plugmap = plate1['PLUGMAP'].data
      # Searching for fiber of qso in data
      wp = np.in1d(plugmap['FIBERID'],ids_)
      # Applying mask to select only QSO
      small_plugmap = plugmap[wp]

      #Get the spectra
      flux=plate1[0].data
      #Get the weight
      ivar=plate1[1].data

      #Get the wavelenght
      pltheader=plate1[0].header
      coeff0=pltheader['COEFF0']
      coeff1=pltheader['COEFF1']
      logwave=coeff0+coeff1*np.arange(flux.shape[1])
      for i in range(0,nqsoPlate_):
            w_ = (10**logwave)/(1+zqso_[i])
            w_crop = ( w_ >= 1040 ) & ( w_ <= lya )
            w_ = w_[w_crop]
            flx = flux[ids_[i]-1][w_crop]
            ivr = ivar[ids_[i]-1][w_crop]
            
            QSOloc.append( np.hstack(( zqso_[i], DEC_[i], RA_[i], ids_[i]  )) )
            s=np.vstack( ( w_.conj().transpose(), flx.conj().transpose(), ivr.conj().transpose() ) )
            spectra.append( s )
   print('Reading done.')         
   return QSOloc, spectra


#####################################
# Load QSO from plates     eBoss
### Parameters
path_spec      = '/work3/desi_lya/data/eBOSS/dr15_all/spplates'
path_drq       = '/work/sfbeltranv/DR14_mini/DR14Q_v4_4m.fits'

# for line correction (later)
#path_lines     = '/work3/desi_lya/data/eBOSS/dr12_all/dr16-line-sky-mask.txt'

zmin = 2
zmax = 4

QSOloc_eBoss, spectra_eBoss = load_eBoss(path_drq, path_spec, zmin, zmax)
# Out:
# Found 234 QSO spec. in catalog: /work/sfbeltranv/DR14_mini/DR14Q_v4_4m.fits
# 0: Loading 1 QSO spec. from plate: spPlate-3668-55478.fits
# 1: Loading 1 QSO spec. from plate: spPlate-3689-55180.fits
# 2: Loading 1 QSO spec. from plate: spPlate-3759-55236.fits
# 3: Loading 1 QSO spec. from plate: spPlate-3815-55537.fits
# 4: Loading 1 QSO spec. from plate: spPlate-3826-55563.fits
# 5: Loading 1 QSO spec. from plate: spPlate-3868-55360.fits
# 6: Loading 1 QSO spec. from plate: spPlate-3922-55333.fits
# 7: Loading 1 QSO spec. from plate: spPlate-3931-55350.fits
# 8: Loading 1 QSO spec. from plate: spPlate-3937-55352.fits
# 9: Loading 1 QSO spec. from plate: spPlate-3940-55327.fits
# 10: Loading 1 QSO spec. from plate: spPlate-3949-55650.fits
# 11: Loading 1 QSO spec. from plate: spPlate-3952-55330.fits
# 12: Loading 2 QSO spec. from plate: spPlate-3980-55331.fits
# 13: Loading 1 QSO spec. from plate: spPlate-4010-55350.fits
# 14: Loading 1 QSO spec. from plate: spPlate-4022-55352.fits
# 15: Loading 1 QSO spec. from plate: spPlate-4058-55358.fits
# 16: Loading 1 QSO spec. from plate: spPlate-4062-55383.fits
# 17: Loading 1 QSO spec. from plate: spPlate-4074-55679.fits
# 18: Loading 1 QSO spec. from plate: spPlate-4077-55361.fits
# 19: Loading 1 QSO spec. from plate: spPlate-4177-55688.fits
# 20: Loading 1 QSO spec. from plate: spPlate-4184-55450.fits
# 21: Loading 1 QSO spec. from plate: spPlate-4232-55447.fits
# 22: Loading 1 QSO spec. from plate: spPlate-4270-55511.fits
# 23: Loading 1 QSO spec. from plate: spPlate-4297-55806.fits
# 24: Loading 1 QSO spec. from plate: spPlate-4298-55511.fits
# 25: Loading 1 QSO spec. from plate: spPlate-4305-55509.fits
# 26: Loading 1 QSO spec. from plate: spPlate-4417-55829.fits
# 27: Loading 1 QSO spec. from plate: spPlate-4424-55532.fits
# 28: Loading 1 QSO spec. from plate: spPlate-4472-55893.fits
# 29: Loading 1 QSO spec. from plate: spPlate-4479-55592.fits
# 30: Loading 1 QSO spec. from plate: spPlate-4496-55544.fits
# 31: Loading 1 QSO spec. from plate: spPlate-4510-55559.fits
# 32: Loading 1 QSO spec. from plate: spPlate-4547-55893.fits
# 33: Loading 1 QSO spec. from plate: spPlate-4550-55894.fits
# 34: Loading 1 QSO spec. from plate: spPlate-4553-55584.fits
# 35: Loading 1 QSO spec. from plate: spPlate-4559-55597.fits
# 36: Loading 1 QSO spec. from plate: spPlate-4570-55623.fits
# 37: Loading 1 QSO spec. from plate: spPlate-4601-55589.fits
# 38: Loading 1 QSO spec. from plate: spPlate-4607-56248.fits
# 39: Loading 1 QSO spec. from plate: spPlate-4618-55600.fits
# 40: Loading 1 QSO spec. from plate: spPlate-4631-55617.fits
# 41: Loading 1 QSO spec. from plate: spPlate-4640-55927.fits
# 42: Loading 1 QSO spec. from plate: spPlate-4710-55707.fits
# 43: Loading 1 QSO spec. from plate: spPlate-4717-55742.fits
# 44: Loading 1 QSO spec. from plate: spPlate-4729-55626.fits
# 45: Loading 1 QSO spec. from plate: spPlate-4743-55645.fits
# 46: Loading 1 QSO spec. from plate: spPlate-4750-55630.fits
# 47: Loading 1 QSO spec. from plate: spPlate-4756-55631.fits
# 48: Loading 1 QSO spec. from plate: spPlate-4783-55652.fits
# 49: Loading 1 QSO spec. from plate: spPlate-4788-55889.fits
# 50: Loading 1 QSO spec. from plate: spPlate-4793-55648.fits
# 51: Loading 1 QSO spec. from plate: spPlate-4797-55662.fits
# 52: Loading 1 QSO spec. from plate: spPlate-4801-55653.fits
# 53: Loading 1 QSO spec. from plate: spPlate-4849-55945.fits
# 54: Loading 1 QSO spec. from plate: spPlate-4856-55712.fits
# 55: Loading 2 QSO spec. from plate: spPlate-4863-55688.fits
# 56: Loading 1 QSO spec. from plate: spPlate-4865-55713.fits
# 57: Loading 1 QSO spec. from plate: spPlate-4869-55896.fits
# 58: Loading 2 QSO spec. from plate: spPlate-4881-55733.fits
# 59: Loading 1 QSO spec. from plate: spPlate-4882-55721.fits
# 60: Loading 1 QSO spec. from plate: spPlate-4974-56038.fits
# 61: Loading 2 QSO spec. from plate: spPlate-4983-55836.fits
# 62: Loading 1 QSO spec. from plate: spPlate-4994-55739.fits
# 63: Loading 1 QSO spec. from plate: spPlate-5015-55707.fits
# 64: Loading 1 QSO spec. from plate: spPlate-5016-55709.fits
# 65: Loading 1 QSO spec. from plate: spPlate-5038-56235.fits
# 66: Loading 1 QSO spec. from plate: spPlate-5060-56181.fits
# 67: Loading 1 QSO spec. from plate: spPlate-5119-55836.fits
# 68: Loading 1 QSO spec. from plate: spPlate-5120-55895.fits
# 69: Loading 1 QSO spec. from plate: spPlate-5125-55863.fits
# 70: Loading 1 QSO spec. from plate: spPlate-5137-55833.fits
# 71: Loading 1 QSO spec. from plate: spPlate-5138-55830.fits
# 72: Loading 1 QSO spec. from plate: spPlate-5140-55836.fits
# 73: Loading 1 QSO spec. from plate: spPlate-5172-56071.fits
# 74: Loading 1 QSO spec. from plate: spPlate-5175-55955.fits
# 75: Loading 1 QSO spec. from plate: spPlate-5181-56298.fits
# 76: Loading 1 QSO spec. from plate: spPlate-5203-56034.fits
# 77: Loading 1 QSO spec. from plate: spPlate-5205-56040.fits
# 78: Loading 1 QSO spec. from plate: spPlate-5206-56033.fits
# 79: Loading 1 QSO spec. from plate: spPlate-5210-56003.fits
# 80: Loading 1 QSO spec. from plate: spPlate-5290-55862.fits
# 81: Loading 1 QSO spec. from plate: spPlate-5291-55947.fits
# 82: Loading 1 QSO spec. from plate: spPlate-5293-55953.fits
# 83: Loading 1 QSO spec. from plate: spPlate-5309-55929.fits
# 84: Loading 1 QSO spec. from plate: spPlate-5310-55983.fits
# 85: Loading 1 QSO spec. from plate: spPlate-5321-55945.fits
# 86: Loading 1 QSO spec. from plate: spPlate-5329-55946.fits
# 87: Loading 1 QSO spec. from plate: spPlate-5343-55999.fits
# 88: Loading 1 QSO spec. from plate: spPlate-5349-55929.fits
# 89: Loading 1 QSO spec. from plate: spPlate-5352-56269.fits
# 90: Loading 1 QSO spec. from plate: spPlate-5355-56009.fits
# 91: Loading 1 QSO spec. from plate: spPlate-5408-56038.fits
# 92: Loading 1 QSO spec. from plate: spPlate-5423-55958.fits
# 93: Loading 1 QSO spec. from plate: spPlate-5426-55987.fits
# 94: Loading 1 QSO spec. from plate: spPlate-5427-56001.fits
# 95: Loading 1 QSO spec. from plate: spPlate-5433-55981.fits
# 96: Loading 1 QSO spec. from plate: spPlate-5437-55973.fits
# 97: Loading 1 QSO spec. from plate: spPlate-5442-55978.fits
# 98: Loading 1 QSO spec. from plate: spPlate-5443-56010.fits
# 99: Loading 1 QSO spec. from plate: spPlate-5444-56038.fits
# 100: Loading 2 QSO spec. from plate: spPlate-5453-56001.fits
# 101: Loading 1 QSO spec. from plate: spPlate-5458-56011.fits
# 102: Loading 1 QSO spec. from plate: spPlate-5460-56000.fits
# 103: Loading 2 QSO spec. from plate: spPlate-5471-56034.fits
# 104: Loading 1 QSO spec. from plate: spPlate-5472-55976.fits
# 105: Loading 1 QSO spec. from plate: spPlate-5697-55944.fits
# 106: Loading 1 QSO spec. from plate: spPlate-5743-56011.fits
# 107: Loading 1 QSO spec. from plate: spPlate-5787-56254.fits
# 108: Loading 1 QSO spec. from plate: spPlate-5809-56353.fits
# 109: Loading 1 QSO spec. from plate: spPlate-5811-56334.fits
# 110: Loading 1 QSO spec. from plate: spPlate-5859-56065.fits
# 111: Loading 1 QSO spec. from plate: spPlate-5882-56029.fits
# 112: Loading 1 QSO spec. from plate: spPlate-5958-56213.fits
# 113: Loading 1 QSO spec. from plate: spPlate-5966-56101.fits
# 114: Loading 1 QSO spec. from plate: spPlate-5978-56073.fits
# 115: Loading 1 QSO spec. from plate: spPlate-5986-56328.fits
# 116: Loading 1 QSO spec. from plate: spPlate-5993-56070.fits
# 117: Loading 1 QSO spec. from plate: spPlate-6003-56311.fits
# 118: Loading 1 QSO spec. from plate: spPlate-6027-56103.fits
# 119: Loading 1 QSO spec. from plate: spPlate-6032-56067.fits
# 120: Loading 1 QSO spec. from plate: spPlate-6059-56093.fits
# 121: Loading 1 QSO spec. from plate: spPlate-6126-56269.fits
# 122: Loading 1 QSO spec. from plate: spPlate-6149-56194.fits
# 123: Loading 2 QSO spec. from plate: spPlate-6158-56239.fits
# 124: Loading 1 QSO spec. from plate: spPlate-6168-56187.fits
# 125: Loading 1 QSO spec. from plate: spPlate-6192-56269.fits
# 126: Loading 1 QSO spec. from plate: spPlate-6261-56219.fits
# 127: Loading 1 QSO spec. from plate: spPlate-6266-56223.fits
# 128: Loading 1 QSO spec. from plate: spPlate-6270-56273.fits
# 129: Loading 1 QSO spec. from plate: spPlate-6281-56295.fits
# 130: Loading 1 QSO spec. from plate: spPlate-6323-56189.fits
# 131: Loading 1 QSO spec. from plate: spPlate-6404-56330.fits
# 132: Loading 1 QSO spec. from plate: spPlate-6413-56336.fits
# 133: Loading 1 QSO spec. from plate: spPlate-6417-56308.fits
# 134: Loading 1 QSO spec. from plate: spPlate-6444-56339.fits
# 135: Loading 1 QSO spec. from plate: spPlate-6466-56310.fits
# 136: Loading 2 QSO spec. from plate: spPlate-6479-56364.fits
# 137: Loading 1 QSO spec. from plate: spPlate-6482-56358.fits
# 138: Loading 1 QSO spec. from plate: spPlate-6488-56364.fits
# 139: Loading 1 QSO spec. from plate: spPlate-6511-56540.fits
# 140: Loading 1 QSO spec. from plate: spPlate-6512-56567.fits
# 141: Loading 1 QSO spec. from plate: spPlate-6519-56566.fits
# 142: Loading 1 QSO spec. from plate: spPlate-6636-56367.fits
# 143: Loading 1 QSO spec. from plate: spPlate-6647-56390.fits
# 144: Loading 1 QSO spec. from plate: spPlate-6665-56390.fits
# 145: Loading 1 QSO spec. from plate: spPlate-6666-56371.fits
# 146: Loading 1 QSO spec. from plate: spPlate-6668-56605.fits
# 147: Loading 1 QSO spec. from plate: spPlate-6681-56419.fits
# 148: Loading 1 QSO spec. from plate: spPlate-6696-56398.fits
# 149: Loading 1 QSO spec. from plate: spPlate-6697-56419.fits
# 150: Loading 1 QSO spec. from plate: spPlate-6705-56636.fits
# 151: Loading 1 QSO spec. from plate: spPlate-6711-56388.fits
# 152: Loading 1 QSO spec. from plate: spPlate-6713-56402.fits
# 153: Loading 1 QSO spec. from plate: spPlate-6722-56431.fits
# 154: Loading 1 QSO spec. from plate: spPlate-6730-56425.fits
# 155: Loading 1 QSO spec. from plate: spPlate-6756-56426.fits
# 156: Loading 1 QSO spec. from plate: spPlate-6787-56447.fits
# 157: Loading 1 QSO spec. from plate: spPlate-6793-56430.fits
# 158: Loading 1 QSO spec. from plate: spPlate-6794-56448.fits
# 159: Loading 1 QSO spec. from plate: spPlate-6804-56447.fits
# 160: Loading 1 QSO spec. from plate: spPlate-6809-56454.fits
# 161: Loading 2 QSO spec. from plate: spPlate-6815-56419.fits
# 162: Loading 1 QSO spec. from plate: spPlate-6826-56449.fits
# 163: Loading 1 QSO spec. from plate: spPlate-6830-56429.fits
# 164: Loading 1 QSO spec. from plate: spPlate-6833-56413.fits
# 165: Loading 1 QSO spec. from plate: spPlate-6839-56425.fits
# 166: Loading 1 QSO spec. from plate: spPlate-6840-56685.fits
# 167: Loading 1 QSO spec. from plate: spPlate-6963-56724.fits
# 168: Loading 1 QSO spec. from plate: spPlate-6970-56444.fits
# 169: Loading 1 QSO spec. from plate: spPlate-6972-56426.fits
# 170: Loading 1 QSO spec. from plate: spPlate-7032-56471.fits
# 171: Loading 1 QSO spec. from plate: spPlate-7092-56683.fits
# 172: Loading 1 QSO spec. from plate: spPlate-7104-56711.fits
# 173: Loading 1 QSO spec. from plate: spPlate-7124-56720.fits
# 174: Loading 1 QSO spec. from plate: spPlate-7127-56566.fits
# 175: Loading 1 QSO spec. from plate: spPlate-7138-56572.fits
# 176: Loading 1 QSO spec. from plate: spPlate-7296-57046.fits
# 177: Loading 1 QSO spec. from plate: spPlate-7298-56661.fits
# 178: Loading 1 QSO spec. from plate: spPlate-7309-56991.fits
# 179: Loading 1 QSO spec. from plate: spPlate-7318-56990.fits
# 180: Loading 1 QSO spec. from plate: spPlate-7387-57038.fits
# 181: Loading 1 QSO spec. from plate: spPlate-7398-56781.fits
# 182: Loading 1 QSO spec. from plate: spPlate-7401-56808.fits
# 183: Loading 1 QSO spec. from plate: spPlate-7412-57162.fits
# 184: Loading 1 QSO spec. from plate: spPlate-7426-56771.fits
# 185: Loading 1 QSO spec. from plate: spPlate-7428-56781.fits
# 186: Loading 1 QSO spec. from plate: spPlate-7573-56946.fits
# 187: Loading 1 QSO spec. from plate: spPlate-7580-56955.fits
# 188: Loading 1 QSO spec. from plate: spPlate-7583-56958.fits
# 189: Loading 1 QSO spec. from plate: spPlate-7585-57190.fits
# 190: Loading 1 QSO spec. from plate: spPlate-7610-56980.fits
# 191: Loading 1 QSO spec. from plate: spPlate-7616-56902.fits
# 192: Loading 1 QSO spec. from plate: spPlate-7657-57309.fits
# 193: Loading 1 QSO spec. from plate: spPlate-7660-57357.fits
# 194: Loading 1 QSO spec. from plate: spPlate-7664-57367.fits
# 195: Loading 1 QSO spec. from plate: spPlate-7679-57367.fits
# 196: Loading 1 QSO spec. from plate: spPlate-7827-57278.fits
# 197: Loading 1 QSO spec. from plate: spPlate-7842-56899.fits
# 198: Loading 1 QSO spec. from plate: spPlate-7860-57006.fits
# 199: Loading 1 QSO spec. from plate: spPlate-8162-56993.fits
# 200: Loading 1 QSO spec. from plate: spPlate-8164-57127.fits
# 201: Loading 1 QSO spec. from plate: spPlate-8166-57130.fits
# 202: Loading 2 QSO spec. from plate: spPlate-8176-57131.fits
# 203: Loading 1 QSO spec. from plate: spPlate-8185-57431.fits
# 204: Loading 1 QSO spec. from plate: spPlate-8194-57401.fits
# 205: Loading 1 QSO spec. from plate: spPlate-8208-57430.fits
# 206: Loading 2 QSO spec. from plate: spPlate-8280-57061.fits
# 207: Loading 1 QSO spec. from plate: spPlate-8288-57419.fits
# 208: Loading 2 QSO spec. from plate: spPlate-8301-57390.fits
# 209: Loading 1 QSO spec. from plate: spPlate-8368-57431.fits
# 210: Loading 1 QSO spec. from plate: spPlate-8382-57513.fits
# 211: Loading 1 QSO spec. from plate: spPlate-8383-57518.fits
# 212: Loading 1 QSO spec. from plate: spPlate-8387-57483.fits
# 213: Loading 1 QSO spec. from plate: spPlate-8401-57482.fits
# 214: Loading 1 QSO spec. from plate: spPlate-8494-57104.fits
# 215: Loading 1 QSO spec. from plate: spPlate-8747-57401.fits
# 216: Loading 1 QSO spec. from plate: spPlate-8791-57373.fits
# 217: Loading 1 QSO spec. from plate: spPlate-8826-57452.fits
# 218: Loading 1 QSO spec. from plate: spPlate-8829-57446.fits
# 219: Loading 1 QSO spec. from plate: spPlate-8835-57427.fits
# 220: Loading 1 QSO spec. from plate: spPlate-8836-57424.fits
# 221: Loading 1 QSO spec. from plate: spPlate-8864-57428.fits
# Reading done.

# %%
def chi2( alpha, *args ):
   a,b = alpha
   w,flux,ivar = args
   return np.sum( (( flux - (a*w+b) )**2 ) * ivar )

# %%
#### One QSO ploting example

for nspectra in range(10,15):
   # nspectra = 100
   s = spectra_eBoss[ nspectra ]
   z, dec, ra = QSOloc_eBoss[nspectra]
   w_ = s[0]
   flux_ = s[1]
   ivar_ = s[2]
   param = scpo.minimize(chi2, (1,1), args=(w_,flux_,ivar_), method='COBYLA' ); #COBYLA
   delta_ = flux_ / (param.x[0]*w_+param.x[1])

   plt.plot(w_,flux_)
   plt.plot(w_,(param.x[0]*w_+param.x[1]))
   plt.plot(w_, delta_ )

   plt.xlabel( 'QSO: Z=' + str( z) + ', DEC=' + str( dec) +', RA=' + str( ra)  )
   plt.show()

# %%
#####################################
# Load QSO from plates     Desi
### Parameters
path_spec      = '/work3/desi_lya/mocks_quick/london/v9.0.0_small/spectra-16'
path_zcat      = '/work/sfbeltranv/DR14_mini/zcat_m.fits'

# for line correction (later)
#path_lines     = '/work3/desi_lya/data/eBOSS/dr12_all/dr16-line-sky-mask.txt'

zmin = 2
zmax = 4

catalog = Table.read(path_zcat)


file = '/work3/desi_lya/mocks_quick/london/v9.0.0_small/spectra-16/10/1005/spectra-16-1005.fits' 
spec = Table.read( file )
#spec

h = pyfits.open( file )

h[0].header[4]

spectra_base= desispec.io.read_spectra( file )

from scipy.signal import medfilt
def plotspec(spectra, i, truewave=None, trueflux=None, color=['b','r','y'],nfilter=11,label=None):
    plt.plot(spectra.wave['b'], medfilt(spectra.flux['b'][i], nfilter), color=color[0], alpha=0.5,label=label)
    plt.plot(spectra.wave['r'], medfilt(spectra.flux['r'][i], nfilter), color=color[1], alpha=0.5)
    plt.plot(spectra.wave['z'], medfilt(spectra.flux['z'][i], nfilter), color=color[2], alpha=0.5)
    if truewave is not None and trueflux is not None:
        plt.plot(truewave, trueflux[i], 'k-')

    plt.axhline(0, color='k', alpha=0.2)
        
    ymax = np.max(spectra.flux['b'][i])
    ymin=0
        
    plt.ylim(ymin, ymax+3)
    plt.ylabel('Flux')
    plt.xlabel('wavelength [A]')
    plt.legend(loc='best')
      
#plt.figure(figsize=(6,10),dpi=100)
#for i in range(5):
#    plt.subplot(5,1,i+1)
#    plotspec(spectra_base, i,label='BASE')

nqso = 34

plt.figure(figsize=(6,3),dpi=100)
plt.plot( spectra_base.wave['b'], spectra_base.flux['b'][nqso], alpha=0.5 )
plt.plot( spectra_base.wave['r'], spectra_base.flux['r'][nqso], alpha=0.5 )
plt.ylabel('Flux intensity')
plt.xlabel(r'$Wavelenght\, (\AA)$')

joint1 = np.in1d( spectra_base.wave['b'], spectra_base.wave['r'])
joint2 = np.in1d( spectra_base.wave['r'], spectra_base.wave['b'])

#plt.figure(figsize=(6,3),dpi=100)
#plt.plot( spectra_base.wave['b'][joint1], spectra_base.flux['b'][nqso][joint1], alpha=0.5 )
#plt.plot( spectra_base.wave['r'][joint2], spectra_base.flux['r'][nqso][joint2], alpha=0.5 )

#plt.figure(figsize=(6,3),dpi=100)
#plt.plot( spectra_base.wave['b'][joint1], spectra_base.ivar['b'][nqso][joint1]*spectra_base.flux['b'][nqso][joint1], alpha=0.5 )
#plt.plot( spectra_base.wave['r'][joint2], spectra_base.ivar['r'][nqso][joint2]*spectra_base.flux['r'][nqso][joint2], alpha=0.5 )

intersec = ( spectra_base.ivar['b'][nqso][joint1]*spectra_base.flux['b'][nqso][joint1] + spectra_base.ivar['r'][nqso][joint2]*spectra_base.flux['r'][nqso][joint2] )
intersec = intersec /( spectra_base.ivar['b'][nqso][joint1] + spectra_base.ivar['r'][nqso][joint2] )

ll = np.concatenate( ( spectra_base.wave['b'][np.invert(joint1)] , spectra_base.wave['r'] ) )

flx = np.concatenate( \
    ( spectra_base.flux['b'][nqso][np.invert(joint1)], intersec, \
     spectra_base.flux['r'][nqso][np.invert(joint2)] ) )


plt.figure(figsize=(6,3),dpi=100)
plt.plot(ll,flx)
plt.plot( spectra_base.wave['b'][joint1], spectra_base.wave['b'][joint1]*0 +1, 'r' )

plt.ylabel('Flux intensity')
#plt.xlabel(r'$Wavelenght\, (\AA)$, $Z_{qso}=$'+str(spectra_base.Z[nqso])+'.')

intersec = ( spectra_base.ivar['b'][nqso][joint1] + spectra_base.ivar['r'][nqso][joint2] ) 
ivr = np.concatenate( ( spectra_base.ivar['b'][nqso][np.invert(joint1)], intersec, \
      spectra_base.ivar['r'][nqso][np.invert(joint2)] ) )

#plt.figure(figsize=(6,3),dpi=100)
#plt.plot(ll,ivr)
#plt.plot( spectra_base.wave['b'][joint1], spectra_base.wave['b'][joint1]*0 +1, 'r' )

plt.ylabel('Flux intensity')
plt.xlabel(r'$Wavelenght\, (\AA)$')

#plt.plot(  spectra_base.flux['b'][0], alpha=0.5 )
#plt.plot(  spectra_base.flux['r'][0], alpha=0.5 )
# Out:
# Text(0.5, 0, '$Wavelenght\\, (\\AA)$')

# %%
def splitID(fi_str):
   fi_str= fi_str.split("spectra-16-")[1]
   return fi_str.split(".fits")[0]


def load_Desi(path_zcat, path_spec, zmin, zmax):
   # Desi Catalog load, beginning of function
   catalog = Table.read(path_zcat)
   qso_string = catalog['SPECTYPE'][0]
   
   lya = 1200 # 1215.67 1200

   
   w = (catalog['SPECTYPE']==qso_string ) & (catalog['Z'] > zmin ) & (catalog['Z']< zmax ) & (catalog['RA']!=catalog['DEC'])& (catalog['RA']>0) & (catalog['DEC']>0)
   reduced_cat = catalog[w]

   nest = True
   in_nside = 16

   targetid = reduced_cat['TARGETID']
   zqso = reduced_cat['Z']
   DEC = reduced_cat['DEC'] * np.pi/180
   RA = reduced_cat['RA'] * np.pi/180

   heal_pix = healpy.ang2pix(in_nside, sp.pi/2.-DEC, RA, nest)
   plate_list = np.unique(heal_pix)
   fi = glob.glob(path_spec+'/*/*/spectra*.fits*')
   print('Found', len(fi), 'spectra files.\n')
   fi_fix = []
   for i in range( 0, len(fi)):
       fi_fix.append( splitID(fi[i]) )

   fi_fix =  np.array( list(map(int, fi_fix)) ) 
   
   print('Found '+ str(  np.sum(w) ) + ' QSO spec. in ' + str( len(plate_list) ) + ' files.' )
   
   spectra = []
   QSOloc = []
   
   ## begin for test
   for nplate in range( 0, len(plate_list) ):      # len(plate_list)
      thisplate = plate_list[ nplate ]
      wp = heal_pix == int( thisplate )
      
      ids_ = targetid[wp]
      zqso_= zqso[wp]
      DEC_ = DEC[wp]
      RA_ = RA[wp]
      heal_pix_ = heal_pix[wp]
      
      # heal_pix: From healpy.ang2pix
      # plate_list: Unique from healpy.ang2pix \n
      # fi_fix: Plate id from directory list
      # fi: All files from glob
      nqsoPlate_= ids_.shape[0]
      # print( str(nplate) + ': Loading '+ str(nqsoPlate_) +' QSO spec. from file: '+ [] )      
      wpf = fi_fix == thisplate
      index = wpf * np.arange( len(fi_fix) )
      index = np.squeeze( index[wpf] )
      
      #print( thisplate,  nqsoPlate_ , len(fi_fix) )
      
      # print( thisplate, fi_fix[index], nqsoPlate_, fi[index] )
      print( str(nplate) + ': Loading '+ str(nqsoPlate_) +' QSO spec. from file: '+  str(thisplate) )
      
      spectra_base = desispec.io.read_spectra( fi[index] )   
      
      joint1 = np.in1d( spectra_base.wave['b'], spectra_base.wave['r'])
      joint2 = np.in1d( spectra_base.wave['r'], spectra_base.wave['b'])
            
      ll = np.concatenate( ( spectra_base.wave['b'][np.invert(joint1)] , spectra_base.wave['r'] ) )

      for i in range(0,nqsoPlate_):
         
         w_ = (ll)/(1+zqso_[ i ])
         w_crop = ( w_ >= 1040 ) & ( w_ <= lya )
         w_ = w_[w_crop] 
         
         intersec = ( spectra_base.ivar['b'][ i ][joint1]*spectra_base.flux['b'][ i ][joint1] + spectra_base.ivar['r'][ i ][joint2]*spectra_base.flux['r'][ i ][joint2] )
         intersec = intersec /( spectra_base.ivar['b'][ i ][joint1] + spectra_base.ivar['r'][ i ][joint2] )

         flx = np.concatenate( ( spectra_base.flux['b'][ i ][np.invert(joint1)], intersec, \
               spectra_base.flux['r'][ i ][np.invert(joint2)] ) )
         flx = flx[w_crop]
         
         intersec = ( spectra_base.ivar['b'][ i ][joint1] + spectra_base.ivar['r'][ i ][joint2] ) 
         ivr = np.concatenate( ( spectra_base.ivar['b'][ i ][np.invert(joint1)], intersec, \
               spectra_base.ivar['r'][ i ][np.invert(joint2)] ) )
         ivr = ivr[w_crop]
      
         QSOloc.append( np.hstack(( zqso_[i], DEC_[i], RA_[i], ids_[i] )) ) 
         s=np.vstack( ( w_.conj().transpose(), flx.conj().transpose(), ivr.conj().transpose() ) )
         spectra.append( s )
   
   print('Reading done.')
   return QSOloc, spectra


path_zcat = '/work/sfbeltranv/DR14_mini/zcat_m.fits' 
path_spec = '/work3/desi_lya/mocks_quick/london/v9.0.0_small/spectra-16'
zmin = 2.
zmax = 4.

QSOloc_Desi, spectra_Desi = load_Desi(path_zcat, path_spec, zmin, zmax)
# Out:
# Found 167 spectra files.
#
# Found 241 QSO spec. in 80 files.
# 0: Loading 6 QSO spec. from file: 0
# 1: Loading 3 QSO spec. from file: 1
# 2: Loading 1 QSO spec. from file: 2
# 3: Loading 7 QSO spec. from file: 8
# 4: Loading 4 QSO spec. from file: 10
# 5: Loading 1 QSO spec. from file: 11
# 6: Loading 5 QSO spec. from file: 14
# 7: Loading 7 QSO spec. from file: 32
# 8: Loading 3 QSO spec. from file: 33
# 9: Loading 3 QSO spec. from file: 34
# 10: Loading 4 QSO spec. from file: 35
# 11: Loading 2 QSO spec. from file: 36
# 12: Loading 3 QSO spec. from file: 37
# 13: Loading 3 QSO spec. from file: 38
# 14: Loading 1 QSO spec. from file: 39
# 15: Loading 9 QSO spec. from file: 40
# 16: Loading 2 QSO spec. from file: 41
# 17: Loading 2 QSO spec. from file: 42
# 18: Loading 2 QSO spec. from file: 44
# 19: Loading 3 QSO spec. from file: 46
# 20: Loading 2 QSO spec. from file: 47
# 21: Loading 1 QSO spec. from file: 56
# 22: Loading 3 QSO spec. from file: 58
# 23: Loading 5 QSO spec. from file: 128
# 24: Loading 3 QSO spec. from file: 129
# 25: Loading 2 QSO spec. from file: 130
# 26: Loading 5 QSO spec. from file: 131
# 27: Loading 4 QSO spec. from file: 132
# 28: Loading 3 QSO spec. from file: 133
# 29: Loading 3 QSO spec. from file: 134
# 30: Loading 4 QSO spec. from file: 135
# 31: Loading 2 QSO spec. from file: 136
# 32: Loading 4 QSO spec. from file: 137
# 33: Loading 2 QSO spec. from file: 138
# 34: Loading 1 QSO spec. from file: 139
# 35: Loading 2 QSO spec. from file: 140
# 36: Loading 1 QSO spec. from file: 142
# 37: Loading 2 QSO spec. from file: 144
# 38: Loading 4 QSO spec. from file: 160
# 39: Loading 2 QSO spec. from file: 161
# 40: Loading 1 QSO spec. from file: 162
# 41: Loading 6 QSO spec. from file: 1000
# 42: Loading 3 QSO spec. from file: 1001
# 43: Loading 3 QSO spec. from file: 1002
# 44: Loading 2 QSO spec. from file: 1006
# 45: Loading 5 QSO spec. from file: 1007
# 46: Loading 1 QSO spec. from file: 1109
# 47: Loading 1 QSO spec. from file: 1110
# 48: Loading 4 QSO spec. from file: 1111
# 49: Loading 3 QSO spec. from file: 1114
# 50: Loading 4 QSO spec. from file: 1115
# 51: Loading 3 QSO spec. from file: 1116
# 52: Loading 1 QSO spec. from file: 1117
# 53: Loading 3 QSO spec. from file: 1118
# 54: Loading 3 QSO spec. from file: 1119
# 55: Loading 2 QSO spec. from file: 1125
# 56: Loading 1 QSO spec. from file: 1126
# 57: Loading 6 QSO spec. from file: 1127
# 58: Loading 1 QSO spec. from file: 1129
# 59: Loading 3 QSO spec. from file: 1130
# 60: Loading 1 QSO spec. from file: 1131
# 61: Loading 2 QSO spec. from file: 1132
# 62: Loading 1 QSO spec. from file: 1133
# 63: Loading 1 QSO spec. from file: 1134
# 64: Loading 2 QSO spec. from file: 1135
# 65: Loading 4 QSO spec. from file: 1136
# 66: Loading 2 QSO spec. from file: 1137
# 67: Loading 2 QSO spec. from file: 1138
# 68: Loading 4 QSO spec. from file: 1139
# 69: Loading 7 QSO spec. from file: 1140
# 70: Loading 1 QSO spec. from file: 1142
# 71: Loading 4 QSO spec. from file: 1143
# 72: Loading 3 QSO spec. from file: 1144
# 73: Loading 2 QSO spec. from file: 1145
# 74: Loading 2 QSO spec. from file: 1146
# 75: Loading 8 QSO spec. from file: 1147
# 76: Loading 1 QSO spec. from file: 1148
# 77: Loading 3 QSO spec. from file: 1149
# 78: Loading 5 QSO spec. from file: 1150
# 79: Loading 4 QSO spec. from file: 1151
# Reading done.

# %%
#### One QSO ploting example

for nspectra in range(0,2):
   # nspectra = 100
   s = spectra_Desi[ nspectra ]
   z, dec, ra, id_ = QSOloc_Desi[ nspectra ]
   w_ = s[0]
   flux_ = s[1]
   ivar_ = s[2]
   param = scpo.minimize(chi2, (1,1), args=(w_,flux_,ivar_), method='COBYLA' ); #COBYLA
   delta_ = flux_ / (param.x[0]*w_+param.x[1])

   plt.plot(w_,flux_)
   plt.plot(w_,(param.x[0]*w_+param.x[1]))
   plt.plot(w_, delta_ )

   plt.xlabel( r'$Wavelenght\, [\AA]$, QSO: Z=' + str( z) + ',\n DEC=' + str( dec) +', RA=' + str( ra)  )
   plt.ylabel( r'$\delta$ (not centered)' )
   plt.show()

# %%
# def comovil distance calculation
def Rcomv(loglam_):
   z = (10**loglam_)/1216 - 1
   return np.interp(z, z_, r_)

# def conversion of r, declination and ra to x y z
def coordC(r,ra,dec):
   return r*np.cos(dec)*np.cos(ra), r*np.cos(dec)*np.sin(ra), r*np.sin(dec)

# %%
# OUTPUT function

#  z     = QSOloc_Desi[ i ][0]
#  dec   = QSOloc_Desi[ i ][1]
#  ra    = QSOloc_Desi[ i ][2]
#  id    = QSOloc_Desi[ i ][3]
#  w_    = spectra_Desi[ i ][ 0 ]
#  flux_ = spectra_Desi[ i ][ 1 ]
#  ivar_ = spectra_Desi[ i ][ 2 ]



def writeDelta(path_out, QSOloc, spectra, cat_type):
# save output
   out = fitsio.FITS(path_out+"/delta.fits.gz",'rw',clobber=True)
   print('Writting data from '+ str(len(QSOloc))+' QSOs')
   if ( cat_type == 'eBoss'):
      for i in range(0, len(QSOloc) ):
         hd = [ {'name':'RA','value':QSOloc[ i ][2],'comment':'Right Ascension [rad]'},
                 {'name':'DEC','value':QSOloc[ i ][1],'comment':'Declination [rad]'},
                 {'name':'Z','value':QSOloc[ i ][0],'comment':'Redshift'},
                 #{'name':'PMF','value':'{}-{}-{}'.format(d.plate,d.mjd,d.fid)},
                 {'name':'FIBER_ID','value':QSOloc[ i ][3],'comment':'Object identification'},
                 #{'name':'PLATE','value':d.plate},
                 #{'name':'MJD','value':d.mjd,'comment':'Modified Julian date'},
                 #{'name':'FIBERID','value':d.fid},
                 {'name':'ORDER','value':1,'comment':'Order of the continuum fit'},
         ]
         cols=[spectra[i][0], spectra[i][1]*0, spectra[i][2], spectra[i][1]]
         names=['WAVELENGHT','DELTA','WEIGHT','CONT']
         units=['Angstrom','','','']
         comments = ['Lambda','Delta field','Pixel weights','Continuum']

         out.write(cols,names=names,header=hd,comment=comments,units=units,extname=str(QSOloc[ i ][3]))
   
   elif ( cat_type == 'Desi'):
      for i in range(0, len(QSOloc) ):
         hd = [ {'name':'RA','value':QSOloc[ i ][2],'comment':'Right Ascension [rad]'},
                 {'name':'DEC','value':QSOloc[ i ][1],'comment':'Declination [rad]'},
                 {'name':'Z','value':QSOloc[ i ][0],'comment':'Redshift'},
                 #{'name':'PMF','value':'{}-{}-{}'.format(d.plate,d.mjd,d.fid)},
                 {'name':'TARGET_ID','value':QSOloc[ i ][3],'comment':'Object identification'},
                 #{'name':'PLATE','value':d.plate},
                 #{'name':'MJD','value':d.mjd,'comment':'Modified Julian date'},
                 #{'name':'FIBERID','value':d.fid},
                 {'name':'ORDER','value':1,'comment':'Order of the continuum fit'},
         ]
         cols=[spectra[i][0], spectra[i][1]*0, spectra[i][2], spectra[i][1]]
         names=['WAVELENGHT','DELTA','WEIGHT','CONT']
         units=['Angstrom','','','']
         comments = ['Lambda','Delta field','Pixel weights','Continuum']

         out.write(cols,names=names,header=hd,comment=comments,units=units,extname=str(QSOloc[ i ][3]))
   
   out.close()
   print('Done writting to file.')

path_out = '/work/sfbeltranv/output/lya-deltas'
writeDelta(path_out, QSOloc_Desi, spectra_Desi, 'Desi')
writeDelta(path_out, QSOloc_eBoss, spectra_eBoss, 'eBoss')
# Out:
# Writting data from 241 QSOs
# Done writting to file.
# Writting data from 234 QSOs
# Done writting to file.

# %%
# easy delta function selection
def f(a,b):
    return a+b
import timeit

deltaF = 'f'


start = timeit.default_timer()
#Your statements here
f(3, 4)
stop = timeit.default_timer()
print('Time: ', stop - start)  

n=3241241
start = timeit.default_timer()
#Your statements here
if n >= 0:
   f(3, 4)
elif(n>45):
   f(4,5)
else:
   f(1,1)
stop = timeit.default_timer()
print('Time: ', stop - start)  

start = timeit.default_timer()
#Your statements here
eval(deltaF)(3, 4)
stop = timeit.default_timer()
print('Time: ', stop - start)
# Out:
# Time:  4.3956562876701355e-05
# Time:  6.801821291446686e-05
# Time:  5.9666112065315247e-05
